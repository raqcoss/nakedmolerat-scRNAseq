# %% [markdown]
# # Data Preprocessing and merging
#
# This notebook contains gene variable homologation to human genes (preserving non-orthologous NMR genes) and QC filtering by finding the local minima.
#
# Finally it merges the NMR data with Human Data According to its region for cross-species cell-type annotation.
#
# ### Pipeline
#
# #### NMR
#
# 1) Load filtered data obtained from cellbender (add .obs[['region', 'species', 'replicate' , 'sample_id']])
# 2) Find mitochondrial and ribosomal genes
# 3) Calculate QC metrics (standard + log1p)
# 4) Set QC thresholds with `find_means.py` per region
# 5) QC Filtering
# 6) Map gene variables to homologus gene variables
# 7) Save counts layer
# 8) Save AnnData object per region
#
# #### Human
# 0) Select and download relevant datasets (adult and developing brain)
# 1) Subsample around 300 cells per cell-type
# 2) Map gene variables to homologus gene variables
# 3) QC + Basic Filtering (use selected thresholds)
# 7) Save counts layer
#
#
# #### Cross-species Dataset
#
# 1) Ensure there is no duplicated genes in nmr or human data (drop duplicated genes with less counts)
# 2) Normalization + log1p
# 3) Select HVGs
# 4) Merge Human and NMR datasets (how='outer, fillna = 0)
# 5) Save AnnData object per region
#
# Available kernel & conda env: `scanpy-env`

# %%
# !ls ../..
# Out:
# big_data			   __marimo__
# data				   miniconda3
# filter_qc_clusters_broken_copy.py  NMR-snRNA-seq
# filter_qc_clusters_copy.py	   output.png
# filter_qc_clusters.py		   qc_clustering_annother_nb_more.ipynb
# layouts

# %%
# Revision number (change every time you run it again)
rev_n = 12
# File paths
path_to_nmr_input_dir = '../../big_data/filtered/'
path_to_human_adult_data = '../../big_data/human/human_adult_GRCh38-3.0.0.h5ad'
path_to_human_dev_data = '../../big_data/human/human_dev.h5ad'
path_to_human_orthology ='../orthology/nmr_human_orthology.csv'
path_to_human_cluster_ann = '../../data/ref/human_glossary.csv'
path_to_human_input_dir = '../../big_data/human'
path_to_output_dir = '../scanpy/results/preprocessing/'

# %%
# Check that all paths are correct
import os
all_paths = [path_to_nmr_input_dir, path_to_human_adult_data, path_to_human_dev_data, path_to_human_orthology, path_to_human_cluster_ann, path_to_human_input_dir]
for path in all_paths:
   if os.path.exists(path):
      print(path,' exists.')
   else: print(path, 'does NOT exist. Please correct it.')
# Out:
# ../../big_data/filtered/  exists.
# ../../big_data/human/human_adult_GRCh38-3.0.0.h5ad  exists.
# ../../big_data/human/human_dev.h5ad  exists.
# ../orthology/nmr_human_orthology.csv  exists.
# ../../data/ref/human_glossary.csv  exists.
# ../../big_data/human  exists.

# %%
import glob
import scanpy as sc
import anndata as ad
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %% [markdown]
# ## Human dataset
#
# Siletti, K., Hodge, R., Mossi Albiach, A., Lee, K. W., Ding, S.-L., Hu, L., Lönnerberg, P., Bakken, T., Casper, T., Clark, M., Dee, N., Gloe, J., Hirschstein, D., Shapovalova, N. V., Keene, C. D., Nyhus, J., Tung, H., Yanny, A. M., Arenas, E., … Linnarsson, S. (2023). **Transcriptomic diversity of cell types across the adult human brain.** Science, 382(6667), eadd7046. https://doi.org/10.1126/science.add7046
#
# https://www.biorxiv.org/content/10.1101/2022.10.12.511898v1.full.pdf

# %%
import pandas as pd
# human_glossary is derivated from linnarsson-lab/adult-human-brain/tables/cluster_annotations.xlsx available at GitHub
cluster_ref = pd.read_csv(path_to_human_cluster_ann)
cluster_ref.set_index('Cluster ID', inplace=True)

print(cluster_ref.columns)
cluster_ref[['Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes', 'Region1', 'Region1_perc']]
# Out:
# Index(['Unnamed: 0', 'Cluster name', 'Supercluster', 'Class auto-annotation',
#        'Neurotransmitter auto-annotation', 'Neuropeptide auto-annotation',
#        'Subtype auto-annotation', 'Transferred MTG Label',
#        'Top Enriched Genes', 'Number of cells', 'Major Field', 'Specific',
#        'Region1', 'Region1_perc', 'Region2', 'Region2_perc'],
#       dtype='object')
#                   Major Field         Supercluster Specific  \
# Cluster ID
# 0                  Non-neuron        Miscellaneous    Bcell
# 1                  Non-neuron        Miscellaneous    Tcell
# 2                  Non-neuron        Miscellaneous   Nkcell
# 3                  Non-neuron        Miscellaneous     Mono
# 4                  Non-neuron            Microglia      Mgl
# ...                       ...                  ...      ...
# 456         Excitatory neuron  Thalamic excitatory     Thex
# 457         Excitatory neuron  Thalamic excitatory     Thex
# 458         Excitatory neuron  Thalamic excitatory     Thex
# 459         Excitatory neuron  Thalamic excitatory     Thex
# 460         Excitatory neuron  Thalamic excitatory     Thex
#
#                                            Top Enriched Genes      Region1  \
# Cluster ID
# 0           IGHM, MS4A1, FCRL1, AC244205.1, IGLL5, IGHA1, ...     Midbrain
# 1           CD2, IL7R, PTPRC, SLFN12L, IL32, CCL5, GRAP2, ...     Midbrain
# 2           NKG7, GNLY, PRF1, KLRF1, PYHIN1, CCL4, RUNX3, ...     Thalamus
# 3           FCN1, CLEC12A, S100A4, TNFRSF1B, IFI30, LYZ, C...     Thalamus
# 4           SRGN, RGS1, GPR183, CD69, HLA-DRA, OLR1, TNFRS...  Spinal cord
# ...                                                       ...          ...
# 456         ST8SIA6, AC012535.1, AC093334.1, ST8SIA6-AS1, ...     Thalamus
# 457         LINC01036, SPTLC3, AC105213.1, SHOX2, LINC0092...     Thalamus
# 458         SPTLC3, NTS, COL6A5, AC105213.1, AL033530.1, C...     Thalamus
# 459         SLC15A1, COL6A5, LHX9, FSHR, LINC01997, SLITRK...     Thalamus
# 460         LINC01239, DMRTA1, MUC7, AC092445.1, AL159156....     Thalamus
#
#             Region1_perc
# Cluster ID
# 0                   21.0
# 1                   15.0
# 2                   17.6
# 3                   21.9
# 4                   31.8
# ...                  ...
# 456                 99.8
# 457                 98.3
# 458                 93.6
# 459                 89.9
# 460                 98.9
#
# [461 rows x 6 columns]

# %%
import plotly.graph_objects as go

# Ensure no NaNs in hierarchical fields
cluster_ref[['Major Field','Supercluster','Specific','Number of cells']] = cluster_ref[['Major Field','Supercluster','Specific','Number of cells']].fillna('Unknown')

# Build node lists
majors = cluster_ref['Major Field'].unique().tolist()
supers = cluster_ref['Supercluster'].unique().tolist()
specifics = cluster_ref['Specific'].unique().tolist()

all_nodes = majors + supers + specifics
node_indices = {name: idx for idx, name in enumerate(all_nodes)}

# Build links: Major -> Supercluster
df_ms = cluster_ref.groupby(['Major Field', 'Supercluster'])['Number of cells'].sum().reset_index()
source = [node_indices[row['Major Field']] for _, row in df_ms.iterrows()]
target = [node_indices[row['Supercluster']] for _, row in df_ms.iterrows()]
value = df_ms['Number of cells'].astype(int).tolist()

# Build links: Supercluster -> Specific
df_ss = cluster_ref.groupby(['Supercluster', 'Specific'])['Number of cells'].sum().reset_index()
source += [node_indices[row['Supercluster']] for _, row in df_ss.iterrows()]
target += [node_indices[row['Specific']] for _, row in df_ss.iterrows()]
value += df_ss['Number of cells'].astype(int).tolist()

fig = go.Figure(data=[go.Sankey(
    node=dict(label=all_nodes, pad=15, thickness=20),
    link=dict(source=source, target=target, value=value)
)])

fig.update_layout(title=f'Reference Human Adult Brain Dataset Compsition by Classes: {len(majors)} Major Fields → {len(supers)} Superclusters → {len(specifics)} Specific classes', height=800, width=1200)
fig.show()

# %%
# Download if it doesn't exists
if os.path.exists(path_to_human_adult_data)!= True:
    # !wget -O {path_to_human_adult_data} 'https://storage.googleapis.com/linnarsson-lab-human/human_adult_GRCh38-3.0.0.h5ad'
else:
    print("File already exists")
# Out:
# File already exists

# %%
# must be 27G
# !du -h /home/ratopin/big_data/human/human_adult_GRCh38-3.0.0.h5ad
# Out:
# 27G	/home/ratopin/big_data/human/human_adult_GRCh38-3.0.0.h5ad

# %%
# Load gene otholog reference table (adapted with `gene_reference.ipynb`)
gene_reference = pd.read_csv(path_to_human_orthology)
gene_reference.set_index('human_gene_acc', inplace=True)
gene_reference.head()
# Out:
#                 human_gene_name nmr_gene_name        nmr_gene_acc  perc_id  \
# human_gene_acc
# ENSG00000175899             A2M           A2m  ENSHGLG00000000871  77.7476
# ENSG00000184389         A3GALT2       A3GALT2  ENSHGLG00000012021  78.2353
# ENSG00000128274          A4GALT        A4GALT  ENSHGLG00000048655  77.0538
# ENSG00000118017           A4GNT         A4GNT  ENSHGLG00000014457  79.3510
# ENSG00000094914            AAAS          AAAS  ENSHGLG00000002843  93.0147
#
#                    orthology_type  human_name_rep  nmr_name_rep human_chr  \
# human_gene_acc
# ENSG00000175899  ortholog_one2one             1.0           1.0        12
# ENSG00000184389  ortholog_one2one             1.0           1.0         1
# ENSG00000128274  ortholog_one2one             1.0           1.0        22
# ENSG00000118017  ortholog_one2one             1.0           1.0         3
# ENSG00000094914  ortholog_one2one             2.0           1.0        12
#
#                 nmr_chr
# human_gene_acc
# ENSG00000175899       5
# ENSG00000184389       7
# ENSG00000128274       5
# ENSG00000118017       8
# ENSG00000094914      17

# %% [markdown]
# ### Sampling a reference human dataset
#
# `human_aldult_GRCh38-3.0.0.h5ad` contains the gene expresssion matrix of 3,369,219 cells and 33,538 genes. In order to use it as a reference, we can sample a subset of the whole dataset to decrease computation resources needed to perform calculation. Only a fraction of randomly selected data is considered in this analysis and 34 cells per cluster were added to improve represtability of low number of cells clusters.

# %%
cluster_ref[['Supercluster', 'Number of cells']].groupby('Supercluster').sum().sort_values(by='Number of cells', ascending=True)
# Out:
#                                      Number of cells
# Supercluster
# Committed oligodendrocyte precursor             4720
# Ependymal                                       5882
# Choroid plexus                                  7689
# Bergmann glia                                   8041
# Fibroblast                                      9156
# Vascular                                        9932
# Hippocampal CA4                                10654
# Cerebellar inhibitory                          14411
# Mammillary body                                16602
# Deep-layer near-projecting                     18856
# Miscellaneous                                  25071
# Eccentric medium spiny neuron                  40144
# LAMP5-LHX6 and Chandelier                      45118
# Lower rhombic lip                              52650
# Hippocampal dentate gyrus                      67533
# Hippocampal CA1-3                              74979
# Deep-layer corticothalamic and 6b              78396
# Thalamic excitatory                            85546
# Microglia                                      91838
# Oligodendrocyte precursor                     105734
# Amygdala excitatory                           109452
# Midbrain-derived inhibitory                   126782
# Upper rhombic lip                             137162
# Medium spiny neuron                           152189
# Astrocyte                                     155025
# MGE interneuron                               222434
# CGE interneuron                               227671
# Deep-layer intratelencephalic                 228467
# Splatter                                      291833
# Upper-layer intratelencephalic                455006
# Oligodendrocyte                               490246

# %%
def subsample_dataset(dataset_path: str, random_seed=71, fraction=0.05, min_per_cluster=34,
                      filter_by=None, add_info_to_stratify_by=None, class_col_name="cluster_id"):
    """
    Subsample an AnnData dataset in backed mode (don't modify backed object).
    Stratifies sampling by grouping cells and ensuring each group is represented.

    Parameters
    ----------
    dataset_path : str
        Path to the AnnData dataset in h5ad format (backed mode).
    random_seed : int, optional
        Random seed for reproducibility. Default is 71.
    fraction : float, optional
        Fraction of cells to sample from each stratification group. Default is 0.05 (5%).
    min_per_cluster : int, optional
        Minimum number of cells to sample from each stratification group. Default is 34.
    filter_by : dict, optional
        Dictionary of column names and regex patterns to filter cells before sampling. Default is None.
    add_info_to_stratify_by : tuple, optional
        Tuple of (column name, mapping dict) to add additional info for stratification. Default is None.
    class_col_name : str, optional
        Column name in obs that contains cluster labels (or the mapped stratification column after cluster_map).
        Default is "cluster_id".

    Returns
    -------
    AnnData
        Subsampled AnnData object.
    """
    dirname = os.path.dirname(dataset_path)
    basename = os.path.basename(dataset_path)
    subset_path = os.path.join(dirname, f"{basename.split(r'.h5')[0]}_subset{random_seed}.h5ad")

    if os.path.exists(subset_path):
        print("Loading existing subset...")
        human_data = sc.read(subset_path)
        print(f"Sampled dataset: {human_data.shape[0]} × {human_data.shape[1]}")
        return human_data

    print("Creating new subset...")
    adata_backed = sc.read_h5ad(dataset_path, backed="r")
    n_obs = adata_backed.n_obs

    # Build combined boolean mask (safe for multiple filters)
    if filter_by:
        mask = np.ones(n_obs, dtype=bool)
        for key, value in filter_by.items():
            if key not in adata_backed.obs.columns:
                raise NameError(f"Column '{key}' not found in obs")
            mask &= adata_backed.obs[key].str.contains(value, regex=True, na=False).values
    else:
        mask = np.ones(n_obs, dtype=bool)

    valid_positions = np.where(mask)[0]  # integer positions in the backed AnnData
    n_cells = len(valid_positions)
    target_size = int(n_cells * fraction)
    print(f"Original: {n_obs} cells, filtered: {n_cells} cells, target {target_size}")

    # Get cluster labels by positional indexing to avoid label/position ambiguity
    original_clusters = adata_backed.obs[class_col_name].iloc[valid_positions].reset_index(drop=True)

    # Map stratify values but fall back to original cluster if mapping misses
    if add_info_to_stratify_by:
        new_col, mapping_dict = add_info_to_stratify_by
        stratify_clusters = original_clusters.map(mapping_dict).fillna('Other').astype(str)
        print(f"Stratifying by mapped column with {stratify_clusters.nunique()} unique values")
    else:
        stratify_clusters = original_clusters.astype(str)

    np.random.seed(random_seed)
    sampled_indices = []
    summary = []

    # Use np.where on the values to guarantee integer positional arrays
    unique_groups = stratify_clusters.unique()
    for clust in unique_groups:
        pos_in_filtered = np.where(stratify_clusters.values == clust)[0]  # integer positions 0..len(valid_positions)-1
        if pos_in_filtered.size == 0:
            continue
        actual_indices = valid_positions[pos_in_filtered]  # convert to dataset row indices
        n_total = len(actual_indices)

        n_sample = int(n_total * fraction) + min_per_cluster
        n_sample = min(n_sample, n_total)

        chosen = np.random.choice(actual_indices, size=n_sample, replace=False)
        chosen_indexes = [int(x) for x in chosen]
        sampled_indices.extend(chosen_indexes)
        summary.append([clust, n_total, n_sample])

    sampled_indices = sorted(sampled_indices)
    if len(sampled_indices) == 0:
        raise ValueError("No cells sampled (check filters / fraction).")

    # Load only sampled cells into memory
    human_data = adata_backed[sampled_indices, :].to_memory()
    print(f"Final sampled dataset: {human_data.shape[0]} × {human_data.shape[1]}")

    df_summary = pd.DataFrame(summary, columns=["cluster", "total_cells", "sampled_cells"])
    df_summary["fraction_sampled"] = df_summary["sampled_cells"] / df_summary["total_cells"]
    print(df_summary.sort_values("total_cells").head(5))
    print("...")
    print(df_summary.sort_values("total_cells").tail(5))

    human_data.write_h5ad(subset_path)
    print(f"Sampled dataset saved to {subset_path}")
    return human_data

# %% [markdown]
# ### Load Human Cerebral Cortex reference

# %%
min_cells_per_type = 100
num_classes = len(cluster_ref['Supercluster'].unique())*.7
print(f'Choosing a dataset size of {min_cells_per_type*num_classes} cells with at least {min_cells_per_type} cells per type.\nWe used only {num_classes} classes in the calculation instead of {len(cluster_ref['Supercluster'].unique())} total classes to account for non-abundant classes.')
# Out:
# Choosing a dataset size of 2170.0 cells with at least 100 cells per type.
# We used only 21.7 classes in the calculation instead of 31 total classes to account for non-abundant classes.

# %%
# 31 Supercluster clases * 300 cells aprox that I want (min 300 cells) / total cells in the dataset (filtered by cortex)
cortex_frac = math.ceil((num_classes*min_cells_per_type)/sc.read_h5ad(path_to_human_adult_data, backed="r").obs['dissection'].str.contains(r'(\(Cx\))|(\(PalCx\))', regex=True, na=False).sum()*1000)/1000
cortex_frac
# this gives around 0.2% of the whole dataset
# Out:
# 0.002

# %%
human_data_cortex = subsample_dataset(path_to_human_adult_data, class_col_name="cluster_id",
                               random_seed=int(str(rev_n)+str(1)), 
                               fraction=cortex_frac,
                               min_per_cluster=min_cells_per_type, 
                               add_info_to_stratify_by=('Supercluster' , cluster_ref['Supercluster'].to_dict()),  # cluster_id → Supercluster
                               filter_by={'dissection': r'(\(Cx\))|(\(PalCx\))'}  # filter to cortex region
                               )
# Out:
# Loading existing subset...
# WARNING: Your filename has more than two extensions: ['.0', '.0_subset121', '.h5ad'].
# Only considering the two last: ['.0_subset121', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.0', '.0_subset121', '.h5ad'].
# Only considering the two last: ['.0_subset121', '.h5ad'].
# Sampled dataset: 4847 × 33538

# %% [markdown]
# ### Load Human Hippocampus reference

# %%
# 31 Supercluster clases 27 * 200 cells aprox that I want (min 300 cells) / total cells in the dataset (filtered by cortex)
hipo_frac = math.ceil((num_classes*min_cells_per_type)/sc.read_h5ad(path_to_human_adult_data, backed="r").obs['dissection'].str.contains(r'\(Hi[TBH]\)', regex=True, na=False).sum()*1000)/1000
hipo_frac

# this gives around 0.7% of the whole dataset
# Out:
# 0.007

# %%
human_data_hipo = subsample_dataset(
    path_to_human_adult_data,
    random_seed=int(str(rev_n)+str(2)), 
    fraction=hipo_frac,
    min_per_cluster=min_cells_per_type, 
    add_info_to_stratify_by=('Supercluster' , cluster_ref['Supercluster'].to_dict()),  # cluster_id → Supercluster
    filter_by={'dissection':r'\(Hi[TBH]\)'}
)
# Out:
# Loading existing subset...
# WARNING: Your filename has more than two extensions: ['.0', '.0_subset122', '.h5ad'].
# Only considering the two last: ['.0_subset122', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.0', '.0_subset122', '.h5ad'].
# Only considering the two last: ['.0_subset122', '.h5ad'].
# Sampled dataset: 4815 × 33538

# %% [markdown]
# ### Load Human Midbrain reference

# %%
# 31 Supercluster clases 30 * 200 cells aprox that I want (min 300 cells) / total cells in the dataset (filtered by cortex)
midbrain_frac = math.ceil((num_classes*min_cells_per_type)/sc.read_h5ad(path_to_human_adult_data, backed="r").obs['dissection'].str.contains(r'(\(M\))|(\(RN\))', regex=True, na=False).sum()*1000)/1000
midbrain_frac

# this gives around 0.9% of the whole dataset
# Out:
# 0.009

# %%
human_data_midbrain = subsample_dataset(
    path_to_human_adult_data,
    random_seed=int(str(rev_n)+str(3)), 
    fraction=midbrain_frac, 
    min_per_cluster=min_cells_per_type,
    add_info_to_stratify_by=('Supercluster' , cluster_ref['Supercluster'].to_dict()),  # cluster_id → Supercluster
    filter_by={'dissection':r'(\(M\))|(\(RN\))'}
)
# Out:
# Loading existing subset...
# WARNING: Your filename has more than two extensions: ['.0', '.0_subset123', '.h5ad'].
# Only considering the two last: ['.0_subset123', '.h5ad'].
# WARNING: Your filename has more than two extensions: ['.0', '.0_subset123', '.h5ad'].
# Only considering the two last: ['.0_subset123', '.h5ad'].
# Sampled dataset: 4439 × 33538

# %%
human_adult_datasets = [human_data_cortex, human_data_hipo, human_data_midbrain]

# %%
# Add some more relevant info
for dataset in human_adult_datasets:
    # Add dataset source
    dataset.obs['dataset_source'] = 'Human Adult Brain (Linnarsson Lab)'
    # Add species
    dataset.obs['species'] = 'human'
    # Add region
    dataset.obs['region']=None
    dataset.obs.loc[dataset.obs['dissection'].str.contains(r'(\(Cx\))|(\(PalCx\))', regex=True), 'region'] = "cerebral cortex"
    dataset.obs.loc[dataset.obs['dissection'].str.contains(r'\(Hi[TBH]\)', regex=True), 'region'] = "hippocampus"
    dataset.obs.loc[dataset.obs['dissection'].str.contains(r'(\(M\))|(\(RN\))', regex=True), 'region'] = "midbrain"
    # Add Major Field, Supercluster and Specific info
    dataset.obs['Major Field'] = dataset.obs['cluster_id'].map(cluster_ref['Major Field'].to_dict())
    dataset.obs['Supercluster'] = dataset.obs['cluster_id'].map(cluster_ref['Supercluster'].to_dict())
    dataset.obs['Specific'] = dataset.obs['cluster_id'].map(cluster_ref['Specific'].to_dict())
    # Add Top Enriched Genes
    dataset.obs['Top Enriched Genes'] = dataset.obs['cluster_id'].map(cluster_ref['Top Enriched Genes'].to_dict())
    # Add human_gene_names (fillna with original gene name if no ortholog found)
    dataset.var['human_gene_name'] = dataset.var_names.map(gene_reference['human_gene_name'])
    dataset.var['human_gene_name'].fillna(dataset.var['Gene'], inplace=True)
    # Add mito genes flag
    dataset.var['mt'] = dataset.var['Gene'].str.startswith('MT-')
    print(f'Found {str(dataset.var["mt"].sum())} mito genes for {dataset.obs['region'][0]}')
# Out:
# Found 13 mito genes for cerebral cortex
# Found 13 mito genes for hippocampus
# Found 13 mito genes for midbrain

# %%
gene_reference.head()
# Out:
#                 human_gene_name nmr_gene_name        nmr_gene_acc  perc_id  \
# human_gene_acc
# ENSG00000175899             A2M           A2m  ENSHGLG00000000871  77.7476
# ENSG00000184389         A3GALT2       A3GALT2  ENSHGLG00000012021  78.2353
# ENSG00000128274          A4GALT        A4GALT  ENSHGLG00000048655  77.0538
# ENSG00000118017           A4GNT         A4GNT  ENSHGLG00000014457  79.3510
# ENSG00000094914            AAAS          AAAS  ENSHGLG00000002843  93.0147
#
#                    orthology_type  human_name_rep  nmr_name_rep human_chr  \
# human_gene_acc
# ENSG00000175899  ortholog_one2one             1.0           1.0        12
# ENSG00000184389  ortholog_one2one             1.0           1.0         1
# ENSG00000128274  ortholog_one2one             1.0           1.0        22
# ENSG00000118017  ortholog_one2one             1.0           1.0         3
# ENSG00000094914  ortholog_one2one             2.0           1.0        12
#
#                 nmr_chr
# human_gene_acc
# ENSG00000175899       5
# ENSG00000184389       7
# ENSG00000128274       5
# ENSG00000118017       8
# ENSG00000094914      17

# %%
a = dataset.var[dataset.var['human_gene_name'].notna()]
a[a['Gene']!=a['human_gene_name']]
# Out:
#                 Chromosome        End        Gene      Start Strand  \
# Accession
# ENSG00000175262          1   10982037    C1orf127   10946471      -
# ENSG00000116922          1   37692249    C1orf109   37681570      -
# ENSG00000284895          1   41628816  AC119676.1   41585306      -
# ENSG00000188396          1   44806675    TCTEX1D4   44805913      -
# ENSG00000250719          1   46176478  AL672043.1   46175486      -
# ...                    ...        ...         ...        ...    ...
# ENSG00000130054          X   69532508     FAM155B   69505241      +
# ENSG00000198908          X  102753540      BHLHB9  102720688      +
# ENSG00000157502          X  106208956      MUM1L1  106168305      +
# ENSG00000080572          X  107244243      PIH1D3  107206632      +
# ENSG00000102125          X  154421726         TAZ  154411518      +
#
#                  human_gene_name     mt
# Accession
# ENSG00000175262            CIROZ  False
# ENSG00000116922            AIRIM  False
# ENSG00000284895  ENSG00000284895  False
# ENSG00000188396           DYNLT4  False
# ENSG00000250719          P3R3URF  False
# ...                          ...    ...
# ENSG00000130054            NALF2  False
# ENSG00000198908          GPRASP3  False
# ENSG00000157502           PWWP3B  False
# ENSG00000080572           DNAAF6  False
# ENSG00000102125         TAFAZZIN  False
#
# [408 rows x 7 columns]

# %%
dataset.var[25:28]
# Out:
#                 Chromosome      End    Gene    Start Strand human_gene_name  \
# Accession
# ENSG00000127054          1  1324691  INTS11  1311585      -          INTS11
# ENSG00000107404          1  1349350    DVL1  1335276      -            DVL1
# ENSG00000162576          1  1361777   MXRA8  1352689      -           MXRA8
#
#                     mt
# Accession
# ENSG00000127054  False
# ENSG00000107404  False
# ENSG00000162576  False

# %% [markdown]
# ## Developing Human Brain
#
# Eze, U.C., Bhaduri, A., Haeussler, M. et al. Single-cell atlas of early human brain development highlights heterogeneity of human neuroepithelial cells and early radial glia. Nat Neurosci 24, 584–594 (2021). https://doi.org/10.1038/s41593-020-00794-1
#
# https://assets.nemoarchive.org/dat-0rsydy7
#
#
# ------
#
# Emelie Braun et al., Comprehensive cell atlas of the first-trimester developing human brain.Science382,eadf1226(2023).DOI:10.1126/science.adf1226
#
# https://github.com/linnarsson-lab/developing-human-brain
#
# File: scanpy/ann_datasets/human_dev.h5ad (Must be 12GB)
#
# This dataset contains 1,665,937 cells, so it is recommended to subsample it.

# %%
# Download Linnarsson lab developing human brain dataset
if os.path.exists(path_to_human_dev_data)!= True:
    # !wget -O {path_to_human_dev_data} 'https://storage.googleapis.com/linnarsson-lab-human/human_dev.h5ad'
else:
    print("File already exists")
# Out:
# File already exists

# %%
# !du -h {path_to_human_dev_data}
# Out:
# 12G	../../big_data/human/human_dev.h5ad

# %%
nemo_links = ['https://data.nemoarchive.org/biccn/grant/u01_devhu/kriegstein/transcriptome/scell/10x_v2/human/processed/counts/GW18_2_hippocampus/GW18_2_hippocampus.mex.tar.gz',
              'https://data.nemoarchive.org/biccn/grant/u01_devhu/kriegstein/transcriptome/scell/10x_v2/human/processed/counts/GW15_wholePFC/GW15_wholePFC.mex.tar.gz',
              'https://data.nemoarchive.org/biccn/grant/u01_devhu/kriegstein/transcriptome/scell/10x_v2/human/processed/counts/CS12_Midbrain/CS12_Midbrain.mex.tar.gz',
              'https://data.nemoarchive.org/biccn/grant/u01_devhu/kriegstein/transcriptome/scell/10x_v2/human/processed/counts/CS14_3_cortex/GRCh38/GRCh38.mex.tar.gz',
              'https://data.nemoarchive.org/biccn/grant/u01_devhu/kriegstein/transcriptome/scell/10x_v2/human/processed/counts/CS14_cortex/CS14_cortex.mex.tar.gz',
              'https://data.nemoarchive.org/biccn/grant/u01_devhu/kriegstein/transcriptome/scell/10x_v2/human/processed/counts/CS14_3_midbrain/GRCh38/GRCh38.mex.tar.gz',
              'https://data.nemoarchive.org/biccn/grant/u01_devhu/kriegstein/transcriptome/scell/10x_v2/human/processed/counts/CS15_2cortex/CS15_2cortex.mex.tar.gz',
              'https://data.nemoarchive.org/biccn/grant/u01_devhu/kriegstein/transcriptome/scell/10x_v2/human/processed/counts/CS15_midbrain/CS15_midbrain.mex.tar.gz']

# %%
#Download Kriegstein lab human developmental brain datasets
# !mkdir -p /home/ratopin/big_data/human/kriegstein/
for link in nemo_links:
    filename = link.split('/')[-1]
    filepath = os.path.join('/home/ratopin/big_data/human/kriegstein/', filename)
    if os.path.exists(filepath) != True:
        # !wget -O {filepath} {link}
    else:
        print(f"File {filename} already exists")
# Out:
# File GW18_2_hippocampus.mex.tar.gz already exists
# File GW15_wholePFC.mex.tar.gz already exists
# File CS12_Midbrain.mex.tar.gz already exists
# File GRCh38.mex.tar.gz already exists
# File CS14_cortex.mex.tar.gz already exists
# File GRCh38.mex.tar.gz already exists
# File CS15_2cortex.mex.tar.gz already exists
# File CS15_midbrain.mex.tar.gz already exists

# %%
# !du -h /home/ratopin/big_data/human/kriegstein/
# Out:
# 174M	/home/ratopin/big_data/human/kriegstein/

# %% [markdown]
# #### Start with Linnarson Lab dataset

# %%
sc.read_h5ad(path_to_human_dev_data, backed="r").obs.head()
# Out:
#                           Age    CellClass Chemistry         Region Subregion  \
# CellID
# 10X89_1:AAACGGGAGGCTACGA  8.0  Erythrocyte        v2  Telencephalon    Cortex
# 10X89_1:ACGAGGAAGAGCCTAG  8.0  Erythrocyte        v2  Telencephalon    Cortex
# 10X89_1:ACGCCAGTCGATAGAA  8.0  Erythrocyte        v2  Telencephalon    Cortex
# 10X89_1:CCGGGATCAGACACTT  8.0  Erythrocyte        v2  Telencephalon    Cortex
# 10X89_1:CGACTTCTCCCACTTG  8.0  Erythrocyte        v2  Telencephalon    Cortex
#
#                          organism_ontology_term_id disease_ontology_term_id  \
# CellID
# 10X89_1:AAACGGGAGGCTACGA            NCBITaxon:9606             PATO:0000461
# 10X89_1:ACGAGGAAGAGCCTAG            NCBITaxon:9606             PATO:0000461
# 10X89_1:ACGCCAGTCGATAGAA            NCBITaxon:9606             PATO:0000461
# 10X89_1:CCGGGATCAGACACTT            NCBITaxon:9606             PATO:0000461
# 10X89_1:CGACTTCTCCCACTTG            NCBITaxon:9606             PATO:0000461
#
#                          self_reported_ethnicity_ontology_term_id  \
# CellID
# 10X89_1:AAACGGGAGGCTACGA                                  unknown
# 10X89_1:ACGAGGAAGAGCCTAG                                  unknown
# 10X89_1:ACGCCAGTCGATAGAA                                  unknown
# 10X89_1:CCGGGATCAGACACTT                                  unknown
# 10X89_1:CGACTTCTCCCACTTG                                  unknown
#
#                          assay_ontology_term_id sex_ontology_term_id  ...  \
# CellID                                                                ...
# 10X89_1:AAACGGGAGGCTACGA            EFO:0009899              unknown  ...
# 10X89_1:ACGAGGAAGAGCCTAG            EFO:0009899              unknown  ...
# 10X89_1:ACGCCAGTCGATAGAA            EFO:0009899              unknown  ...
# 10X89_1:CCGGGATCAGACACTT            EFO:0009899              unknown  ...
# 10X89_1:CGACTTCTCCCACTTG            EFO:0009899              unknown  ...
#
#                          dissection tissue_ontology_term_id  \
# CellID
# 10X89_1:AAACGGGAGGCTACGA     Cortex          UBERON:0001851
# 10X89_1:ACGAGGAAGAGCCTAG     Cortex          UBERON:0001851
# 10X89_1:ACGCCAGTCGATAGAA     Cortex          UBERON:0001851
# 10X89_1:CCGGGATCAGACACTT     Cortex          UBERON:0001851
# 10X89_1:CGACTTCTCCCACTTG     Cortex          UBERON:0001851
#
#                          cell_type_ontology_term_id fraction_mitochondrial  \
# CellID
# 10X89_1:AAACGGGAGGCTACGA                 CL:0000232               0.000000
# 10X89_1:ACGAGGAAGAGCCTAG                 CL:0000232               0.003857
# 10X89_1:ACGCCAGTCGATAGAA                 CL:0000232               0.008797
# 10X89_1:CCGGGATCAGACACTT                 CL:0000232               0.001594
# 10X89_1:CGACTTCTCCCACTTG                 CL:0000232               0.001869
#
#                          fraction_unspliced cell_cycle_score total_genes  \
# CellID
# 10X89_1:AAACGGGAGGCTACGA           0.351404         0.000000         121
# 10X89_1:ACGAGGAAGAGCCTAG           0.338333         0.000107         271
# 10X89_1:ACGCCAGTCGATAGAA           0.317455         0.000000         674
# 10X89_1:CCGGGATCAGACACTT           0.325893         0.000957         101
# 10X89_1:CGACTTCTCCCACTTG           0.358561         0.000000         113
#
#                           total_UMIs  sample_id  cluster_id
# CellID
# 10X89_1:AAACGGGAGGCTACGA        4630    10X89_1         240
# 10X89_1:ACGAGGAAGAGCCTAG        9334    10X89_1         240
# 10X89_1:ACGCCAGTCGATAGAA        9321    10X89_1         236
# 10X89_1:CCGGGATCAGACACTT        3136    10X89_1         240
# 10X89_1:CGACTTCTCCCACTTG        4281    10X89_1         233
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### Cerebral Cortex

# %%
num_classes_dev = len(sc.read_h5ad(path_to_human_dev_data, backed="r").obs['CellClass'].unique())*1
print(f'{num_classes_dev} classes considered')
# Out:
# 12 classes considered

# %%
cortex_frac_dev = math.ceil((num_classes_dev*min_cells_per_type)/sc.read_h5ad(path_to_human_dev_data, backed="r").obs['Subregion'].value_counts().loc['Cortex']*1000)/1000
cortex_frac_dev
# Out:
# 0.005

# %%
dev_human_cortex = subsample_dataset(path_to_human_dev_data,random_seed=int(str(rev_n)+str(1)), 
                                     fraction=cortex_frac_dev, min_per_cluster=min_cells_per_type, 
                                     filter_by={'Subregion':'Cortex'}, 
                                     class_col_name='CellClass')
# Out:
# Loading existing subset...
# Sampled dataset: 2269 × 59459

# %% [markdown]
# ##### Hippocampus

# %%
hipo_frac_dev = math.ceil((cortex_frac_dev*min_cells_per_type)/sc.read_h5ad(path_to_human_dev_data, backed="r").obs['Subregion'].value_counts().loc['Hippocampus']*1000)/1000
hipo_frac_dev
# Out:
# 0.001

# %%
dev_human_hipo = subsample_dataset(path_to_human_dev_data,random_seed=int(str(rev_n)+str(2)), 
                                     fraction=hipo_frac_dev, min_per_cluster=min_cells_per_type, 
                                     filter_by={'Subregion':'Hippocampus'}, 
                                     class_col_name='CellClass')
# Out:
# Loading existing subset...
# Sampled dataset: 931 × 59459

# %%
midbrain_frac_dev = math.ceil((cortex_frac_dev*min_cells_per_type)/sc.read_h5ad(path_to_human_dev_data, backed="r").obs['Subregion'].value_counts().loc['Midbrain']*1000)/1000
midbrain_frac_dev
# Out:
# 0.001

# %%
dev_human_midbrain = subsample_dataset(path_to_human_dev_data,random_seed=int(str(rev_n)+str(3)), 
                                     fraction=midbrain_frac_dev, min_per_cluster=min_cells_per_type, 
                                     filter_by={'Subregion':'Midbrain'}, 
                                     class_col_name='CellClass')
# Out:
# Loading existing subset...
# Sampled dataset: 1281 × 59459

# %%
human_dev_datasets = [dev_human_cortex, dev_human_hipo, dev_human_midbrain]

# %%
cells_per_class = sc.read_h5ad(path_to_human_dev_data, backed="r").obs['CellClass'].value_counts()

# %%
cells_per_class
# Out:
# CellClass
# Neuron          561754
# Radial glia     519908
# Neuroblast      285699
# Glioblast       132420
# Neuronal IPC    110260
# Fibroblast       19161
# Vascular         11741
# Erythrocyte       8958
# Immune            8102
# Oligo             6190
# Placodes           873
# Neural crest       871
# Name: count, dtype: int64

# %%
cellclass_ref = pd.read_excel('../../data/ref/human_dev_glossary.xlsx',index_col=0)
cellclass_ref
# Out:
#                     Major Field     Supercluster  Specific  \
# CellClass
# Erythrocyte          Non-neuron         Vascular       Ery
# Fibroblast           Non-neuron       Fibroblast       Fbl
# Glioblast     Neural progenitor        Glioblast       Gbm
# Immune               Non-neuron        Microglia       Mgl
# Neural crest  Neural progenitor     Neural crest  NeuCrest
# Neuroblast    Neural progenitor       Neuroblast       Nbl
# Neuron        Neural progenitor           Neuron       Neu
# Neuronal IPC  Neural progenitor     Neuronal IPC    NeuIPC
# Oligo                Non-neuron  Oligodendrocyte     Oligo
# Placodes      Neural progenitor         Placodes  Placodes
# Radial glia   Neural progenitor      Radial Glia       Rgl
# Vascular             Non-neuron         Vascular     VendC
#
#                                              Top Level Enriched
# CellClass
# Erythrocyte   HBZ,HBE1,HBB,HBA1,AC104389.6,HBM,HBA2,AHSP,ALA...
# Fibroblast    COL1A1,COL3A1,IGF2,PTGDS,TWIST1,LUM,DCN,COL1A2...
# Glioblast     AQP4,HEPN1,SPARCL1,HEPACAM,BCAN,MT3,PMP2,CFAP1...
# Immune        SPP1,C1QC,AIF1,TYROBP,C1QB,CCL3,C1QA,P2RY12,CC...
# Neural crest  COL1A1,COL3A1,IGF2,PTGDS,TWIST1,LUM,DCN,COL1A2...
# Neuroblast    SIM1,FEV,PITX2,OTP,SLC17A8,FOXA2,TH,PMCH,TPH2,...
# Neuron        TFAP2D,LHX9,C1QL4,POU4F1,MAB21L1,OBI1-AS1,EBF2...
# Neuronal IPC  DLX1,SOX1-OT,DLX2,BEST3,IL33,MYBL1,ST8SIA5,AK5...
# Oligo         BCAS1,APOD,OLIG1,PDGFRA,SOX10,S100B,KLRC2,AL35...
# Placodes      SIX1,PRPH,ISL2,SNCG,THSD7B,PPP1R1C,RGS10,ISL1,...
# Radial glia   AMBN,DMRT3,AL354863.1,EMX2,EMX2OS,DMRTA2,B3GAT...
# Vascular      CLEC3B,FLT1,SOX18,CLDN5,ITM2A,SLC38A5,PECAM1,E...

# %%
counts = cells_per_class.copy()

# Align counts to cellclass_ref index (CellClass) and fill missing with 0
counts = counts.reindex(cellclass_ref.index).fillna(0).astype(int)

# Build node lists
majors = cellclass_ref['Major Field'].fillna('Unknown').unique().tolist()
supers = cellclass_ref['Supercluster'].fillna('Unknown').unique().tolist()
specifics = cellclass_ref['Specific'].fillna('Unknown').unique().tolist()

all_nodes = list(majors) + list(supers) + list(specifics)
node_idx = {name: idx for idx, name in enumerate(all_nodes)}

# Major -> Supercluster links: aggregate counts of all CellClass rows under each pair
df = cellclass_ref.join(counts.rename('n_cells'))
df_ms = df.groupby(['Major Field', 'Supercluster'])['n_cells'].sum().reset_index()
source = [node_idx[row['Major Field']] for _, row in df_ms.iterrows()]
target = [node_idx[row['Supercluster']] for _, row in df_ms.iterrows()]
value = df_ms['n_cells'].astype(int).tolist()

# Supercluster -> Specific links: use counts per Specific (sum across CellClass entries mapping to the Specific)
df_ss = df.groupby(['Supercluster', 'Specific'])['n_cells'].sum().reset_index()
source += [node_idx[row['Supercluster']] for _, row in df_ss.iterrows()]
target += [node_idx[row['Specific']] for _, row in df_ss.iterrows()]
value += df_ss['n_cells'].astype(int).tolist()

# Plot Sankey
fig = go.Figure(data=[go.Sankey(
    arrangement='snap',
    node=dict(
        label=all_nodes,
        pad=12,
        thickness=18,
        color=(['#636EFA']*len(majors) + ['#EF553B']*len(supers) + ['#00CC96']*len(specifics))
    ),
    link=dict(source=source, target=target, value=value)
)])
fig.update_layout(title_text='Major Field → Supercluster → Specific (cell counts)', height=800, width=1200, font_size=11)
fig.show()

# %%
# Add relevant info
for dataset in human_dev_datasets:
    # Add dataset source
    dataset.obs['dataset_source'] = 'Human Developing Brain (Linnarsson Lab)'
    # Add species
    dataset.obs['species'] = 'human'
    # Add region
    dataset.obs['region']=None
    dataset.obs['region'] = dataset.obs['Subregion'].replace({'Cortex':'cerebral cortex',
                                                             'Hippocampus':'hippocampus',
                                                             'Midbrain ventral':'midbrain',
                                                             'Midbrain dorsal':'midbrain',
                                                             'Midbrain':'midbrain'})
    # Add Major Field, Supercluster and Specific info
    dataset.obs['Major Field'] = dataset.obs['CellClass'].map(cellclass_ref['Major Field'].to_dict())
    dataset.obs['Supercluster'] = dataset.obs['CellClass'].map(cellclass_ref['Supercluster'].to_dict())
    dataset.obs['Specific'] = dataset.obs['CellClass'].map(cellclass_ref['Specific'].to_dict())
    # Add Top Enriched Genes
    dataset.obs['Top Enriched Genes'] = dataset.obs['CellClass'].map(cellclass_ref['Top Level Enriched'].to_dict())
    # Homolog gene accesion name (Drop last part of the Accession to match gene_reference)
    dataset.var['Accession'] = [acc.split('.')[0] if pd.notna(acc) else acc for acc in dataset.var['Accession']]
    # Add human_gene_names (fillna with original gene name if no ortholog found)
    dataset.var['human_gene_name'] = dataset.var['Accession'].map(gene_reference['human_gene_name'])
    dataset.var['human_gene_name'].fillna(dataset.var['Gene'], inplace=True)
    # Find mito genes
    dataset.var['mt'] = dataset.var['Gene'].str.startswith('MT-')
    print(f'Found {str(dataset.var["mt"].sum())} mito genes for {dataset.obs['region'][0]}')
# Out:
# Found 37 mito genes for cerebral cortex
# Found 37 mito genes for hippocampus
# Found 37 mito genes for midbrain

# %%
dataset.var.head()
# Out:
#                          Accession Chromosome    End  GeneTotalUMIs  Start  \
# Accession
# ENSG00000223972.5  ENSG00000223972       chr1  14409              3  11869
# ENSG00000227232.5  ENSG00000227232       chr1  29570         104073  14404
# ENSG00000278267.1  ENSG00000278267       chr1  17436              0  17369
# ENSG00000284332.1  ENSG00000284332       chr1  30503              0  30366
# ENSG00000268020.3  ENSG00000268020       chr1  53312              0  52473
#
#                         Gene human_gene_name     mt
# Accession
# ENSG00000223972.5    DDX11L1         DDX11L1  False
# ENSG00000227232.5     WASH7P          WASH7P  False
# ENSG00000278267.1  MIR6859-1       MIR6859-1  False
# ENSG00000284332.1  MIR1302-2       MIR1302-2  False
# ENSG00000268020.3     OR4G4P          OR4G4P  False

# %% [markdown]
# ## Naked Mole Rat Datasets

# %%
nmr_files = sorted(glob.glob('/home/ratopin/big_data/filtered/*_filtered.h5ad'))
nmr_files
# Out:
# ['/home/ratopin/big_data/filtered/NMR1_cerebral_filtered.h5ad',
#  '/home/ratopin/big_data/filtered/NMR2_cerebral_filtered.h5ad',
#  '/home/ratopin/big_data/filtered/NMR3_hippocampus_filtered.h5ad',
#  '/home/ratopin/big_data/filtered/NMR4_hippocampus_filtered.h5ad',
#  '/home/ratopin/big_data/filtered/NMR5_midbrain_filtered.h5ad',
#  '/home/ratopin/big_data/filtered/NMR6_midbrain_filtered.h5ad']

# %%
# Load gene otholog reference table (adapted with `gene_reference.ipynb`)
gene_reference = pd.read_csv(path_to_human_orthology)
gene_reference.head()
# Out:
#   human_gene_name   human_gene_acc nmr_gene_name        nmr_gene_acc  perc_id  \
# 0             A2M  ENSG00000175899           A2m  ENSHGLG00000000871  77.7476
# 1         A3GALT2  ENSG00000184389       A3GALT2  ENSHGLG00000012021  78.2353
# 2          A4GALT  ENSG00000128274        A4GALT  ENSHGLG00000048655  77.0538
# 3           A4GNT  ENSG00000118017         A4GNT  ENSHGLG00000014457  79.3510
# 4            AAAS  ENSG00000094914          AAAS  ENSHGLG00000002843  93.0147
#
#      orthology_type  human_name_rep  nmr_name_rep human_chr nmr_chr
# 0  ortholog_one2one             1.0           1.0        12       5
# 1  ortholog_one2one             1.0           1.0         1       7
# 2  ortholog_one2one             1.0           1.0        22       5
# 3  ortholog_one2one             1.0           1.0         3       8
# 4  ortholog_one2one             2.0           1.0        12      17

# %%
nmr_adatas = []
nmr_gene_map = dict(zip(gene_reference['nmr_gene_acc'], gene_reference['human_gene_name']))
nmr_gene_chr_map = dict(zip(gene_reference['nmr_gene_acc'],gene_reference['nmr_chr']))

for file in nmr_files:
    # CellBender output should be read with read_10x_h5
    try: 
        adata = sc.read_10x_h5(file)
    except:
        adata = sc.read(file)

    adata.var['species'] = 'nmr'

    sample = file.replace('/home/ratopin/big_data/filtered/NMR', '').replace('_filtered.h5ad', '').split('_', 1)
    sample_id = sample[0]
    tissue = sample[1]

    print(f'Loading sample {sample_id} of {tissue}')

    adata.obs['species'] = 'nmr'
    adata.obs['tissue'] = tissue
    adata.obs['sample_id'] = sample_id
    adata.obs['replicate'] = (int(sample_id)+1)%2+1

    # Map NMR gene IDs to global names
    adata.var['genome'] = 'HetGla_female1'
    adata.var['chromosome'] = adata.var['gene_ids'].map(nmr_gene_chr_map)
    adata.var['global_name'] = adata.var['gene_ids'].map(nmr_gene_map)
    adata.var['global_name'].fillna(pd.Series(adata.var.index, index=adata.var.index), inplace=True)
    nmr_adatas.append(adata)

nmr_adatas
# Out:
# Loading sample 1 of cerebral
# Loading sample 2 of cerebral
# Loading sample 3 of hippocampus
# Loading sample 4 of hippocampus
# Loading sample 5 of midbrain
# Loading sample 6 of midbrain
# [AnnData object with n_obs × n_vars = 11353 × 20774
#      obs: 'species', 'sample', 'tissue', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts', 'qc_composite', 'qc_label', 'sample_id', 'replicate'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'tf', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'species', 'chromosome', 'global_name',
#  AnnData object with n_obs × n_vars = 16526 × 20774
#      obs: 'species', 'sample', 'tissue', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts', 'qc_composite', 'qc_label', 'sample_id', 'replicate'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'tf', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'qc_gene', 'species', 'chromosome', 'global_name',
#  AnnData object with n_obs × n_vars = 6284 × 20774
#      obs: 'species', 'sample', 'tissue', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts', 'qc_composite', 'qc_label', 'sample_id', 'replicate'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'tf', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'qc_gene', 'species', 'chromosome', 'global_name',
#  AnnData object with n_obs × n_vars = 8027 × 20774
#      obs: 'species', 'sample', 'tissue', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts', 'qc_composite', 'qc_label', 'sample_id', 'replicate'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'tf', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'qc_gene', 'species', 'chromosome', 'global_name',
#  AnnData object with n_obs × n_vars = 4467 × 20774
#      obs: 'species', 'sample', 'tissue', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts', 'qc_composite', 'qc_label', 'sample_id', 'replicate'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'tf', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'qc_gene', 'species', 'chromosome', 'global_name',
#  AnnData object with n_obs × n_vars = 4669 × 20774
#      obs: 'species', 'sample', 'tissue', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts', 'qc_composite', 'qc_label', 'sample_id', 'replicate'
#      var: 'gene_ids', 'feature_types', 'genome', 'mt', 'ribo', 'hb', 'tf', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'qc_gene', 'species', 'chromosome', 'global_name']

# %%
nmr_adatas[0].var[nmr_adatas[0].var['global_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [gene_ids, feature_types, genome, mt, ribo, hb, tf, n_cells_by_counts, mean_counts, log1p_mean_counts, pct_dropout_by_counts, total_counts, log1p_total_counts, species, chromosome, global_name]
# Index: []

# %%
for ad in nmr_adatas:
    if 'global_name' not in ad.var.columns:
        ad.var['global_name'] = ad.var.index
    ad.var_names_make_unique()

# %%
samples = [os.path.basename(f).replace('_filtered.h5ad', '').split('_',1)[0] for f in nmr_files]

# %%
cortex_nmr_adata = sc.concat(nmr_adatas[0:2],axis=0, join='outer', label='sample', keys=samples[0:2], index_unique='-')
hipo_nmr_adata = sc.concat(nmr_adatas[2:4],axis=0, join='outer', label='sample', keys=samples[2:4], index_unique='-')
midbrain_nmr_adata = sc.concat(nmr_adatas[4:6],axis=0, join='outer', label='sample', keys=samples[4:6], index_unique='-')

# %%
cortex_nmr_adata.obs['tissue'] = "cerebral cortex"

# %%
nmr_datas = [cortex_nmr_adata, hipo_nmr_adata, midbrain_nmr_adata]

# %% [markdown]
# #### QC basic filtering
#
# - Cerebral cortex: total counts > 200
# - Hippocampus: total counts > 200
# - Midbrain: total counts > 45 *This filtering is not useful for this sample anyway, so another type of filtering is needed.

# %%
nmr_mito_genes = open('./mito_genes.txt', 'r').read().splitlines()
human_ribo_genes = pd.read_csv('./human_ribo_genes.csv', header=1)
human_ribo_genes = human_ribo_genes['Approved symbol'].tolist()
len(human_ribo_genes)
# Out:
# 247

# %%
for adata in nmr_datas:
    print(adata.obs['tissue'][0])
    # mitochondrial genes, "MT-" for human, "Mt-" for mouse
    if 'mt' not in adata.var.columns:
        try: adata.var["mt"] = adata.var['Chromosome'] == 'MT'
        except: adata.var["mt"] = adata.var_names.str.startswith(("mt-", "MT-","Mt-")) |[gene in nmr_mito_genes for gene in adata.var_names]
    print(f'Found {adata.var["mt"].sum()} mito genes.')
    # ribosomal genes
    try: adata.var["ribo"] = [name in human_ribo_genes for name in adata.var['Gene']]
    except: adata.var["ribo"] = adata.var_names.str.startswith(("RPS", "RPL", "Rpl", "Rps"))
    print(f'Found {adata.var["ribo"].sum()} ribo genes.\n')
    sc.pp.calculate_qc_metrics(adata, qc_vars=["mt", "ribo"], inplace=True)
# Out:
# cerebral cortex
# Found 13 mito genes.
# Found 78 ribo genes.
#
# hippocampus
# Found 13 mito genes.
# Found 78 ribo genes.
#
# midbrain
# Found 13 mito genes.
# Found 78 ribo genes.

# %%
min_total_counts  = [200,200,30]

# %%
print('Total cells:', nmr_datas[0].n_obs)
print(f'total_counts <= {min_total_counts[0]}:\n',nmr_datas[0].obs[nmr_datas[0].obs['total_counts']<=min_total_counts[0]].value_counts('sample'))
print('Remaining cells:', nmr_datas[0].n_obs- len(nmr_datas[0].obs[nmr_datas[0].obs['total_counts']<=min_total_counts[0]]))

print('\nTotal cells:', nmr_datas[1].n_obs)
print(f'total_counts <= {min_total_counts[1]}:\n',nmr_datas[1].obs[nmr_datas[1].obs['total_counts']<=min_total_counts[1]].value_counts('sample'))
print('Remaining cells:', nmr_datas[1].n_obs- len(nmr_datas[1].obs[nmr_datas[1].obs['total_counts']<=min_total_counts[1]]))

print('\nTotal cells:', nmr_datas[2].n_obs)
print(f'total_counts <= {min_total_counts[2]}:\n',nmr_datas[2].obs[nmr_datas[2].obs['total_counts']<=min_total_counts[2]].value_counts('sample'))
print('Remaining cells:', nmr_datas[2].n_obs- len(nmr_datas[2].obs[nmr_datas[2].obs['total_counts']<=min_total_counts[2]]))
# Out:
# Total cells: 27879
# total_counts <= 200:
#  sample
# NMR2    2331
# NMR1    1156
# Name: count, dtype: int64
# Remaining cells: 24392
#
# Total cells: 14311
# total_counts <= 200:
#  sample
# NMR4    349
# NMR3    283
# Name: count, dtype: int64
# Remaining cells: 13679
#
# Total cells: 9136
# total_counts <= 30:
#  sample
# NMR5    406
# NMR6    390
# Name: count, dtype: int64
# Remaining cells: 8340

# %%
from special_functions import plot_qc_violin_with_thres

# %%
import matplotlib.pyplot as plt

qc_cuts = {"n_genes_by_counts":[3,3,3], 
        "min_total_counts":[200,200,30], 
        "max_total_counts":[22000,22000,10000],
        "pct_counts_mt": [3,3,3], 
        'pct_counts_ribo': [7,7,7]}

# Map tissue types to indices
tissue_to_idx = {"cerebral_cortex": 0, "hippocampus": 1, "midbrain": 2}

# Loop through all datasets
for adata in nmr_datas:
    tissue = adata.obs['tissue'].iloc[0]
    print(f"Plotting {tissue}")
    
    idx = tissue_to_idx.get(tissue, 0)
    
    # Create plot with seaborn for better control
    plot_keys = ["n_genes_by_counts", "total_counts", "pct_counts_mt", 'pct_counts_ribo']
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    
    for i, key in enumerate(plot_keys):
        # Create violin plot with seaborn
        data_to_plot = adata.obs[[key]].copy()
        sns.violinplot(data=data_to_plot, y=key, ax=axes[i], color='skyblue')
        
        # Add jitter points on top
        sns.stripplot(data=data_to_plot, y=key, ax=axes[i], color='black', alpha=0.4, size=1, jitter=1 )
        
        # Add threshold lines
        if key == "total_counts":
            axes[i].axhline(y=qc_cuts['min_total_counts'][idx], color='red', linestyle='--', linewidth=2, alpha=1, label=f'min: {qc_cuts["min_total_counts"][idx]}')
            axes[i].axhline(y=qc_cuts['max_total_counts'][idx], color='red', linestyle='--', linewidth=2, alpha=0.7, label=f'max: {qc_cuts["max_total_counts"][idx]}')
            axes[i].legend()
        elif key in qc_cuts:
            threshold = qc_cuts[key][idx]
            axes[i].axhline(y=threshold, color='red', linestyle='--', linewidth=2, alpha=0.8, label=f'threshold: {threshold}')
            axes[i].legend()
        
        axes[i].set_title(f'{key}', fontsize=12)
    
    fig.suptitle(f'{tissue}', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()
# Out:
# Plotting cerebral cortex
# Plotting hippocampus
# Plotting midbrain

# %%
# Filter out low-quality cells in nmr data
filtered_nmr_datas = []
for i, adata in enumerate(nmr_datas):
    print(f'Filtering {adata.obs["tissue"].iloc[0]} NMR data:')
    nmr_data = adata.copy()
    nmr_data = nmr_data[nmr_data.obs['total_counts'] > qc_cuts['min_total_counts'][i],:]
    nmr_data = nmr_data[nmr_data.obs['total_counts'] < qc_cuts['max_total_counts'][i],:]
    nmr_data = nmr_data[nmr_data.obs['pct_counts_mt'] < qc_cuts['pct_counts_mt'][i],:]
    nmr_data = nmr_data[nmr_data.obs['pct_counts_ribo'] < qc_cuts['pct_counts_ribo'][i],:]
    sc.pp.filter_genes(nmr_data, min_cells=qc_cuts['n_genes_by_counts'][i], inplace=True)
    filtered_nmr_datas.append(nmr_data)
    print(f'Filtered {adata.obs["tissue"].iloc[0]} NMR data: {adata.n_obs} cells, {adata.n_vars} genes → {nmr_data.n_obs} cells, {nmr_data.n_vars} genes.\n')
# Out:
# Filtering cerebral cortex NMR data:
# Filtered cerebral cortex NMR data: 27879 cells, 20774 genes → 24378 cells, 17413 genes.
#
# Filtering hippocampus NMR data:
# Filtered hippocampus NMR data: 14311 cells, 20774 genes → 13634 cells, 17592 genes.
#
# Filtering midbrain NMR data:
# Filtered midbrain NMR data: 9136 cells, 20774 genes → 8070 cells, 13915 genes.

# %%
## Save NMR datas
for nmr_data in filtered_nmr_datas:
    tissue = nmr_data.obs['tissue'].iloc[0].replace(" ", "_")
    filename = f'/home/ratopin/big_data/nmr/{tissue}_nmr_adata_filtered{rev_n}.h5ad'
    nmr_data.write_h5ad(filename)
    print(f"AnnData from NMR {tissue} successfully saved to {filename}")
# Out:
# AnnData from NMR cerebral_cortex successfully saved to /home/ratopin/big_data/nmr/cerebral_cortex_nmr_adata_filtered12.h5ad
# AnnData from NMR hippocampus successfully saved to /home/ratopin/big_data/nmr/hippocampus_nmr_adata_filtered12.h5ad
# AnnData from NMR midbrain successfully saved to /home/ratopin/big_data/nmr/midbrain_nmr_adata_filtered12.h5ad

# %% [markdown]
# ## Check human QC metrics

# %%
human_adult_datasets
# Out:
# [AnnData object with n_obs × n_vars = 4847 × 33538
#      obs: 'Tissue', 'TotalUMIs', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'total_UMIs', 'sample_id', 'cluster_id', 'roi', 'dataset_source', 'species', 'region', 'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes'
#      var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'human_gene_name', 'mt'
#      uns: 'batch_condition', 'schema_version', 'title',
#  AnnData object with n_obs × n_vars = 4815 × 33538
#      obs: 'Tissue', 'TotalUMIs', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'total_UMIs', 'sample_id', 'cluster_id', 'roi', 'dataset_source', 'species', 'region', 'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes'
#      var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'human_gene_name', 'mt'
#      uns: 'batch_condition', 'schema_version', 'title',
#  AnnData object with n_obs × n_vars = 4439 × 33538
#      obs: 'Tissue', 'TotalUMIs', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'total_UMIs', 'sample_id', 'cluster_id', 'roi', 'dataset_source', 'species', 'region', 'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes'
#      var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'human_gene_name', 'mt'
#      uns: 'batch_condition', 'schema_version', 'title']

# %%
human_dev_datasets
# Out:
# [AnnData object with n_obs × n_vars = 2269 × 59459
#      obs: 'Age', 'CellClass', 'Chemistry', 'Region', 'Subregion', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'tissue_type', 'dissection', 'tissue_ontology_term_id', 'cell_type_ontology_term_id', 'fraction_mitochondrial', 'fraction_unspliced', 'cell_cycle_score', 'total_genes', 'total_UMIs', 'sample_id', 'cluster_id', 'dataset_source', 'species', 'region', 'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes'
#      var: 'Accession', 'Chromosome', 'End', 'GeneTotalUMIs', 'Start', 'Gene', 'human_gene_name', 'mt'
#      uns: 'batch_condition', 'title'
#      obsm: 'Factors', 'X_Embedding'
#      varm: 'Loadings',
#  AnnData object with n_obs × n_vars = 931 × 59459
#      obs: 'Age', 'CellClass', 'Chemistry', 'Region', 'Subregion', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'tissue_type', 'dissection', 'tissue_ontology_term_id', 'cell_type_ontology_term_id', 'fraction_mitochondrial', 'fraction_unspliced', 'cell_cycle_score', 'total_genes', 'total_UMIs', 'sample_id', 'cluster_id', 'dataset_source', 'species', 'region', 'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes'
#      var: 'Accession', 'Chromosome', 'End', 'GeneTotalUMIs', 'Start', 'Gene', 'human_gene_name', 'mt'
#      uns: 'batch_condition', 'title'
#      obsm: 'Factors', 'X_Embedding'
#      varm: 'Loadings',
#  AnnData object with n_obs × n_vars = 1281 × 59459
#      obs: 'Age', 'CellClass', 'Chemistry', 'Region', 'Subregion', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'tissue_type', 'dissection', 'tissue_ontology_term_id', 'cell_type_ontology_term_id', 'fraction_mitochondrial', 'fraction_unspliced', 'cell_cycle_score', 'total_genes', 'total_UMIs', 'sample_id', 'cluster_id', 'dataset_source', 'species', 'region', 'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes'
#      var: 'Accession', 'Chromosome', 'End', 'GeneTotalUMIs', 'Start', 'Gene', 'human_gene_name', 'mt'
#      uns: 'batch_condition', 'title'
#      obsm: 'Factors', 'X_Embedding'
#      varm: 'Loadings']

# %%
human_adult_datasets[0].var
# Out:
#                 Chromosome       End        Gene     Start Strand  \
# Accession
# ENSG00000237613          1     36081     FAM138A     34554      -
# ENSG00000238009          1    133723  AL627309.1     89295      -
# ENSG00000239945          1     91105  AL627309.3     89551      -
# ENSG00000239906          1    140339  AL627309.2    139790      -
# ENSG00000284733          1    451697      OR4F29    450703      -
# ...                    ...       ...         ...       ...    ...
# ENSG00000235412          Y  24607025      TTTY4B  24570202      +
# ENSG00000183795          Y  24639207       BPY2B  24607560      +
# ENSG00000205916          Y  24907040        DAZ4  24833843      +
# ENSG00000172288          Y  25624902        CDY1  25622162      +
# ENSG00000231141          Y  25733388       TTTY3  25728490      +
#
#                 human_gene_name     mt
# Accession
# ENSG00000237613         FAM138A  False
# ENSG00000238009      AL627309.1  False
# ENSG00000239945      AL627309.3  False
# ENSG00000239906      AL627309.2  False
# ENSG00000284733          OR4F29  False
# ...                         ...    ...
# ENSG00000235412          TTTY4B  False
# ENSG00000183795           BPY2B  False
# ENSG00000205916            DAZ4  False
# ENSG00000172288            CDY1  False
# ENSG00000231141           TTTY3  False
#
# [33538 rows x 7 columns]

# %%
for adata in human_dev_datasets:
    adata.var.index = adata.var['Accession']
    adata.var.drop(columns='Accession', inplace=True)

# %%
human_dev_datasets[0].var
# Out:
#                        Chromosome     End  GeneTotalUMIs   Start         Gene  \
# Accession
# ENSG00000223972              chr1   14409              3   11869      DDX11L1
# ENSG00000227232              chr1   29570         104073   14404       WASH7P
# ENSG00000278267              chr1   17436              0   17369    MIR6859-1
# ENSG00000284332              chr1   30503              0   30366    MIR1302-2
# ENSG00000268020              chr1   53312              0   52473       OR4G4P
# ...                           ...     ...            ...     ...          ...
# ENSG00000275757  chr22_KI270733v1  174108              0  173956  5_8S_rRNA-8
# ENSG00000278573  chr22_KI270734v1   60316              0   59711   AC007325.3
# ENSG00000276017  chr22_KI270734v1   74814             15   72411   AC007325.1
# ENSG00000278625  chrUn_KI270744v1   51114              0   51009        U6-29
# ENSG00000277374  chrUn_KI270750v1  148843              0  148668         U1-5
#
#                 human_gene_name     mt
# Accession
# ENSG00000223972         DDX11L1  False
# ENSG00000227232          WASH7P  False
# ENSG00000278267       MIR6859-1  False
# ENSG00000284332       MIR1302-2  False
# ENSG00000268020          OR4G4P  False
# ...                         ...    ...
# ENSG00000275757     5_8S_rRNA-8  False
# ENSG00000278573      AC007325.3  False
# ENSG00000276017      AC007325.1  False
# ENSG00000278625           U6-29  False
# ENSG00000277374            U1-5  False
#
# [59459 rows x 7 columns]

# %%
for dataset_list in [human_adult_datasets, human_dev_datasets]:
    for adata in dataset_list:
        print(adata.obs['region'][0])
        # mitochondrial genes, "MT-" for human, "Mt-" for mouse
        if 'mt' not in nmr_data.var.columns:
            try: adata.var["mt"] = adata.var['Chromosome'] == 'MT'
            except: adata.var["mt"] = adata.var_names.str.startswith(("mt-", "MT-","Mt-")) |[gene in nmr_mito_genes for gene in adata.var_names]
        print(f'Found {adata.var["mt"].sum()} mito genes.')
        # ribosomal genes
        try: adata.var["ribo"] = [name in human_ribo_genes for name in adata.var['Gene']]
        except: adata.var["ribo"] = adata.var_names.str.startswith(("RPS", "RPL", "Rpl", "Rps"))
        print(f'Found {adata.var["ribo"].sum()} ribo genes.\n')
        sc.pp.calculate_qc_metrics(adata, qc_vars=["mt", "ribo"], inplace=True)
# Out:
# cerebral cortex
# Found 13 mito genes.
# Found 171 ribo genes.
#
# hippocampus
# Found 13 mito genes.
# Found 171 ribo genes.
#
# midbrain
# Found 13 mito genes.
# Found 171 ribo genes.
#
# cerebral cortex
# Found 37 mito genes.
# Found 171 ribo genes.
#
# hippocampus
# Found 37 mito genes.
# Found 171 ribo genes.
#
# midbrain
# Found 37 mito genes.
# Found 171 ribo genes.

# %%
from special_functions import plot_qc_violin_with_thres

# %%
qc_cuts_adult = {
        "n_genes_by_counts":3, 
        "min_total_counts":200,
        "max_total_counts":60000,
        "pct_counts_mt": 5,
        'pct_counts_ribo': 10}
for adata in human_adult_datasets:
    plt, axes = plot_qc_violin_with_thres(adata, qc_cuts=qc_cuts_adult)
    plt.tight_layout()
    plt.show()
# Out:
# Plotting cerebral cortex
# Plotting hippocampus
# Plotting midbrain

# %%
qc_cuts_dev={
        "n_genes_by_counts":3, 
        "min_total_counts":200,
        "max_total_counts":60000,
        "pct_counts_mt": 5,
        'pct_counts_ribo': np.inf}
for adata in human_dev_datasets:
    plt, axes = plot_qc_violin_with_thres(adata, qc_cuts=qc_cuts_dev)
    plt.tight_layout()
    plt.show()
# Out:
# Plotting cerebral cortex
# Plotting hippocampus
# Plotting midbrain

# %%
# Filter out low-quality cells in human adult data
filtered_adult_datasets = []
for i, adata in enumerate(human_adult_datasets):
    print(f'Filtering {adata.obs["region"].iloc[0]} human adult data:')
    filtered_data = adata.copy()
    filtered_data = filtered_data[filtered_data.obs['total_counts'] > qc_cuts_adult['min_total_counts'],:]
    filtered_data = filtered_data[filtered_data.obs['total_counts'] < qc_cuts_adult['max_total_counts'],:]
    filtered_data = filtered_data[filtered_data.obs['pct_counts_mt'] < qc_cuts_adult['pct_counts_mt'],:]
    filtered_data = filtered_data[filtered_data.obs['pct_counts_ribo'] < qc_cuts_adult['pct_counts_ribo'],:]
    sc.pp.filter_genes(filtered_data, min_cells=qc_cuts_adult['n_genes_by_counts'], inplace=True)
    filtered_adult_datasets.append(filtered_data)
    print(f'Filtered {adata.obs["region"].iloc[0]} NMR data: {adata.n_obs} cells, {adata.n_vars} genes → {filtered_data.n_obs} cells, {filtered_data.n_vars} genes.\n')
# Out:
# Filtering cerebral cortex human adult data:
# Filtered cerebral cortex NMR data: 4847 cells, 33538 genes → 4665 cells, 26188 genes.
#
# Filtering hippocampus human adult data:
# Filtered hippocampus NMR data: 4815 cells, 33538 genes → 4572 cells, 26197 genes.
#
# Filtering midbrain human adult data:
# Filtered midbrain NMR data: 4439 cells, 33538 genes → 4128 cells, 25633 genes.

# %%
# Filter out low-quality cells in human dev data
filtered_dev_datasets = []
for i, adata in enumerate(human_dev_datasets):
    print(f'Filtering {adata.obs["region"].iloc[0]} developing human data:')
    filtered_data = adata.copy()
    filtered_data = filtered_data[filtered_data.obs['total_counts'] > qc_cuts_dev['min_total_counts'],:]
    filtered_data = filtered_data[filtered_data.obs['total_counts'] < qc_cuts_dev['max_total_counts'],:]
    filtered_data = filtered_data[filtered_data.obs['pct_counts_mt'] < qc_cuts_dev['pct_counts_mt'],:]
    filtered_data = filtered_data[filtered_data.obs['pct_counts_ribo'] < qc_cuts_dev['pct_counts_ribo'],:]
    sc.pp.filter_genes(filtered_data, min_cells=qc_cuts_dev['n_genes_by_counts'], inplace=True)
    filtered_dev_datasets.append(filtered_data)
    print(f'Filtered {adata.obs["region"].iloc[0]} NMR data: {adata.n_obs} cells, {adata.n_vars} genes → {filtered_data.n_obs} cells, {filtered_data.n_vars} genes.\n')
# Out:
# Filtering cerebral cortex developing human data:
# Filtered cerebral cortex NMR data: 2269 cells, 59459 genes → 2000 cells, 25595 genes.
#
# Filtering hippocampus developing human data:
# Filtered hippocampus NMR data: 931 cells, 59459 genes → 659 cells, 22642 genes.
#
# Filtering midbrain developing human data:
# Filtered midbrain NMR data: 1281 cells, 59459 genes → 947 cells, 22642 genes.

# %%
for adata in filtered_adult_datasets:
    plt, axes = plot_qc_violin_with_thres(adata, qc_cuts=qc_cuts_adult)
    plt.tight_layout()
    plt.show()
# Out:
# Plotting cerebral cortex
# Plotting hippocampus
# Plotting midbrain

# %%
for adata in filtered_dev_datasets:
    plt, axes = plot_qc_violin_with_thres(adata, qc_cuts=qc_cuts_dev)
    plt.tight_layout()
    plt.show()
# Out:
# Plotting cerebral cortex
# Plotting hippocampus
# Plotting midbrain

# %%
for adata in filtered_adult_datasets:
    adata.obs['stage'] = 'adult'
for adata in filtered_dev_datasets:
    adata.obs['stage'] = 'developing'

# %%
## Save human filtered dataset subsets
for adata in filtered_adult_datasets:
    tissue = adata.obs['region'].iloc[0].replace(" ", "_")
    stage =  adata.obs['stage'].iloc[0]
    filename = f'/home/ratopin/big_data/human/{tissue}_human_{stage}_adata_filtered{rev_n}.h5ad'
    adata.write_h5ad(filename)
    print(f"AnnData from human {stage} - {tissue} successfully saved to {filename}")
# Out:
# AnnData from human adult - cerebral_cortex successfully saved to /home/ratopin/big_data/human/cerebral_cortex_human_adult_adata_filtered12.h5ad
# AnnData from human adult - hippocampus successfully saved to /home/ratopin/big_data/human/hippocampus_human_adult_adata_filtered12.h5ad
# AnnData from human adult - midbrain successfully saved to /home/ratopin/big_data/human/midbrain_human_adult_adata_filtered12.h5ad

# %%
## Save human filtered dataset subsets
for adata in filtered_dev_datasets:
    tissue = adata.obs['region'].iloc[0].replace(" ", "_")
    stage =  adata.obs['stage'].iloc[0]
    filename = f'/home/ratopin/big_data/human/{tissue}_human_{stage}_adata_filtered{rev_n}.h5ad'
    adata.write_h5ad(filename)
    print(f"AnnData from human {stage} - {tissue} successfully saved to {filename}")
# Out:
# AnnData from human developing - cerebral_cortex successfully saved to /home/ratopin/big_data/human/cerebral_cortex_human_developing_adata_filtered12.h5ad
# AnnData from human developing - hippocampus successfully saved to /home/ratopin/big_data/human/hippocampus_human_developing_adata_filtered12.h5ad
# AnnData from human developing - midbrain successfully saved to /home/ratopin/big_data/human/midbrain_human_developing_adata_filtered12.h5ad

# %% [markdown]
# ## Tidy up adatas prior to merging
# Subset each human dataset.var by only shared genes by at least 2 species (nmr & human)

# %% [markdown]
# ### Tidy up Human
#
# For each region of human (adult and dev) adata:
#
# 1. Map genes to gene_reference['human_gene_name']
#
# 2. **Drop NaNs** (non-orthologus genes between human and nmr)
#
# 3. Drop duplicates (In case the gene names repeat for a pair of accesion numbers)
#
# 4. Set ['human_gene_name'] column to var_names

# %%
gene_reference[["human_gene_acc", "human_gene_name"]]
# Out:
#         human_gene_acc  human_gene_name
# 0      ENSG00000175899              A2M
# 1      ENSG00000184389          A3GALT2
# 2      ENSG00000128274           A4GALT
# 3      ENSG00000118017            A4GNT
# 4      ENSG00000094914             AAAS
# ...                ...              ...
# 14976  ENSG00000164761        TNFRSF11B
# 14977  ENSG00000126602            TRAP1
# 14978  ENSG00000146469              VIP
# 14979  ENSG00000156853           ZNF689
# 14980  ENSG00000284895  ENSG00000284895
#
# [14981 rows x 2 columns]

# %%
from scipy import sparse

def drop_lower_count_duplicates(adata, gene_key="global_name", verbose=True):
    """
    Remove duplicated genes by keeping the one with highest global expression.
    Prints info about duplicates if verbose=True.
    
    Parameters
    ----------
    adata : AnnData
    gene_key : str
        Column in `adata.var` to identify gene names (default "global_name").
    verbose : bool
        If True, print duplicate genes and their counts.
    
    Returns
    -------
    AnnData with unique genes
    """
    # Get gene names
    if gene_key in adata.var.columns:
        genes = adata.var[gene_key].astype(str)
    else:
        genes = adata.var_names.astype(str)

    # Compute total counts per gene (sparse-aware)
    if sparse.issparse(adata.X):
        total_counts = np.array(adata.X.sum(axis=0)).flatten()
    else:
        total_counts = adata.X.sum(axis=0)

    # Build dataframe
    df = pd.DataFrame({
        "gene": genes.values,
        "total_counts": total_counts,
        "idx": np.arange(len(genes))
    })

    # Find duplicates
    dupes = df[df.duplicated("gene", keep=False)].sort_values("gene")

    if verbose and not dupes.empty:
        print("\nDuplicate genes found:")
        for g, sub in dupes.groupby("gene"):
            print(f"  {g}:")
            for _, row in sub.iterrows():
                print(f"    idx={row['idx']} total_counts={row['total_counts']}")
    
    # Keep max count per gene
    keep_idx = df.loc[df.groupby("gene")["total_counts"].idxmax(), "idx"].values

    # Subset AnnData
    adata_unique = adata[:, keep_idx].copy()
    adata_unique.var_names = genes.iloc[keep_idx].values

    return adata_unique

# %%
for lst in (filtered_adult_datasets, filtered_dev_datasets):
    for i in range(len(lst)):
        adata = lst[i]
        print(f"{adata.obs['stage'].iloc[0]} - {adata.obs['region'].iloc[0]}: {adata.n_obs} cells, {adata.n_vars} genes")
        print(adata.var_names[:5])
        # Map gene accession to global names
        adata.var['global_name'] = adata.var_names.map(gene_reference.set_index('human_gene_acc')['human_gene_name'])
        # Keep only genes with a mapped global_name by subsetting the AnnData (must match adata.n_vars)
        mask = adata.var['global_name'].notna()
        print(f"Mapped global names: {mask.sum()} / {adata.n_vars}")
        adata = adata[:, mask].copy()
        print(f"After dropping NaN global names: {adata.n_obs} cells, {adata.n_vars} genes")
        # Drop duplicates (keeps the higher-count gene)
        adata = drop_lower_count_duplicates(adata)
        print(f'After droping duplicates: {adata.n_obs} cells, {adata.n_vars} genes')
        # Set global_name as var_names and make unique
        adata.var_names = adata.var['global_name']
        adata.var_names_make_unique()
        # Put the modified AnnData back into the tidy list
        lst[i] = adata
# Out:
# adult - cerebral cortex: 4665 cells, 26188 genes
# Index(['ENSG00000238009', 'ENSG00000239945', 'ENSG00000225880',
#        'ENSG00000230368', 'ENSG00000223764'],
#       dtype='object', name='Accession')
# Mapped global names: 13342 / 26188
# After dropping NaN global names: 4665 cells, 13342 genes
# After droping duplicates: 4665 cells, 13342 genes
# adult - hippocampus: 4572 cells, 26197 genes
# Index(['ENSG00000238009', 'ENSG00000225880', 'ENSG00000230368',
#        'ENSG00000223764', 'ENSG00000188976'],
#       dtype='object', name='Accession')
# Mapped global names: 13365 / 26197
# After dropping NaN global names: 4572 cells, 13365 genes
# After droping duplicates: 4572 cells, 13365 genes
# adult - midbrain: 4128 cells, 25633 genes
# Index(['ENSG00000238009', 'ENSG00000239945', 'ENSG00000225880',
#        'ENSG00000230368', 'ENSG00000223764'],
#       dtype='object', name='Accession')
# Mapped global names: 13305 / 25633
# After dropping NaN global names: 4128 cells, 13305 genes
# After droping duplicates: 4128 cells, 13305 genes
# developing - cerebral cortex: 2000 cells, 25595 genes
# Index(['ENSG00000227232', 'ENSG00000268903', 'ENSG00000241860',
#        'ENSG00000279457', 'ENSG00000228463'],
#       dtype='object', name='Accession')
# Mapped global names: 12844 / 25595
# After dropping NaN global names: 2000 cells, 12844 genes
#
# Duplicate genes found:
#   ASMTL:
#     idx=12399 total_counts=6.0
#     idx=12828 total_counts=5.0
#   CD99:
#     idx=12401 total_counts=13.0
#     idx=12830 total_counts=23.0
#   DHRSX:
#     idx=12400 total_counts=22.0
#     idx=12829 total_counts=29.0
#   IL3RA:
#     idx=12398 total_counts=11.0
#     idx=12827 total_counts=15.0
#   PLCXD1:
#     idx=12397 total_counts=6.0
#     idx=12825 total_counts=4.0
# After droping duplicates: 2000 cells, 12839 genes
# developing - hippocampus: 659 cells, 22642 genes
# Index(['ENSG00000227232', 'ENSG00000279457', 'ENSG00000228463',
#        'ENSG00000230021', 'ENSG00000225630'],
#       dtype='object', name='Accession')
# Mapped global names: 12322 / 22642
# After dropping NaN global names: 659 cells, 12322 genes
#
# Duplicate genes found:
#   CD99:
#     idx=11902 total_counts=7.0
#     idx=12308 total_counts=4.0
#   DHRSX:
#     idx=11901 total_counts=14.0
#     idx=12307 total_counts=17.0
# After droping duplicates: 659 cells, 12320 genes
# developing - midbrain: 947 cells, 22642 genes
# Index(['ENSG00000227232', 'ENSG00000279457', 'ENSG00000228463',
#        'ENSG00000230021', 'ENSG00000225630'],
#       dtype='object', name='Accession')
# Mapped global names: 12465 / 22642
# After dropping NaN global names: 947 cells, 12465 genes
#
# Duplicate genes found:
#   CD99:
#     idx=12043 total_counts=6.0
#     idx=12451 total_counts=9.0
#   DHRSX:
#     idx=12042 total_counts=9.0
#     idx=12450 total_counts=11.0
#   IL3RA:
#     idx=12041 total_counts=4.0
#     idx=12448 total_counts=4.0
# After droping duplicates: 947 cells, 12462 genes

# %%
filtered_adult_datasets[0].var_names
# Out:
# Index(['A1CF', 'A2M', 'A3GALT2', 'A4GALT', 'A4GNT', 'AAAS', 'AACS', 'AADAT',
#        'AAGAB', 'AAK1',
#        ...
#        'ZSWIM8', 'ZSWIM9', 'ZUP1', 'ZW10', 'ZWILCH', 'ZWINT', 'ZXDC', 'ZYX',
#        'ZZEF1', 'ZZZ3'],
#       dtype='object', name='global_name', length=13342)

# %% [markdown]
# #### Tidy up NMR
#
#
# For each region of nmr adata:
#
# 1. Map genes to gene_reference['human_gene_name']
#
# 2. **Fill NaNs** with original nmr genes (preserve nmr genes for future analysis)
#
# 3. Drop duplicates (In case any gene name repeats during orthologus merging)
#
# 4. Set ['human_gene_name'] column to var_names

# %%
for i in range(len(filtered_nmr_datas)):
    adata = filtered_nmr_datas[i]
    print(f"{adata.obs['tissue'].iloc[0]}: {adata.n_obs} cells, {adata.n_vars} genes")
    print(adata.var_names[:5])
    adata.var['global_name'] = adata.var_names.map(dict(zip(gene_reference['nmr_gene_name'], gene_reference['human_gene_name'])))
    adata.var['original_names'] = adata.var_names.to_list()
    adata.var['global_name'].fillna(adata.var['original_names'], inplace=True)
    # Drop duplicates (keeps the higher-count gene)
    adata = drop_lower_count_duplicates(adata)
    print(f'After droping duplicates: {adata.n_obs} cells, {adata.n_vars} genes')
    # Set global_name as var_names and make unique
    adata.var_names = adata.var['global_name']
    adata.var_names_make_unique()
    # Put the modified AnnData back into the tidy list
    filtered_nmr_datas[i] = adata
# Out:
# cerebral cortex: 24378 cells, 17413 genes
# Index(['ZMYND10', 'AMIGO3', 'TNFSF10', 'NPRL2', 'GMPPB'], dtype='object')
#
# Duplicate genes found:
#   ACP1:
#     idx=10175 total_counts=168.0
#     idx=14752 total_counts=158.0
#   AKAP7:
#     idx=5409 total_counts=70.0
#     idx=5430 total_counts=1480.0
#   AMD1:
#     idx=14615 total_counts=32.0
#     idx=16699 total_counts=2714.0
#   AMN:
#     idx=1703 total_counts=215.0
#     idx=17171 total_counts=307.0
#   APPL2:
#     idx=12220 total_counts=4250.0
#     idx=4543 total_counts=672.0
#   AR:
#     idx=9406 total_counts=631.0
#     idx=15730 total_counts=225.0
#   ARG1:
#     idx=5437 total_counts=740.0
#     idx=7371 total_counts=58.0
#   ARID3C:
#     idx=1841 total_counts=127.0
#     idx=1869 total_counts=488.0
#   ASIP:
#     idx=14508 total_counts=46.0
#     idx=12141 total_counts=6949.0
#   BNC1:
#     idx=15519 total_counts=71908.0
#     idx=8109 total_counts=3.0
#   BRCC3:
#     idx=17267 total_counts=1872.0
#     idx=12214 total_counts=822.0
#   BRF1:
#     idx=1734 total_counts=331.0
#     idx=1757 total_counts=3820.0
#   BRI3:
#     idx=3490 total_counts=157.0
#     idx=14805 total_counts=77.0
#   CAP1:
#     idx=7254 total_counts=1230.0
#     idx=10189 total_counts=89.0
#   CAST:
#     idx=2972 total_counts=2187.0
#     idx=16609 total_counts=340.0
#   CCR4:
#     idx=1211 total_counts=3952.0
#     idx=9855 total_counts=984.0
#   CCT2:
#     idx=4512 total_counts=2833.0
#     idx=3723 total_counts=5.0
#   CCT6B:
#     idx=15523 total_counts=99.0
#     idx=8625 total_counts=7.0
#   CDH1:
#     idx=4150 total_counts=10.0
#     idx=13725 total_counts=1582.0
#   CDH20:
#     idx=8596 total_counts=25.0
#     idx=9993 total_counts=17915.0
#   CDH7:
#     idx=9954 total_counts=1500.0
#     idx=9955 total_counts=478.0
#   CKLF:
#     idx=4149 total_counts=1609.0
#     idx=4378 total_counts=245.0
#   CSNK1E:
#     idx=5277 total_counts=1083.0
#     idx=15552 total_counts=11.0
#   DCAF11:
#     idx=12585 total_counts=339.0
#     idx=12580 total_counts=89.0
#   DCUN1D4:
#     idx=4862 total_counts=31.0
#     idx=5560 total_counts=4234.0
#   DIO1:
#     idx=17066 total_counts=396.0
#     idx=2835 total_counts=985.0
#   DLC1:
#     idx=14251 total_counts=12891.0
#     idx=8230 total_counts=573.0
#   DLG3:
#     idx=10958 total_counts=1535.0
#     idx=16151 total_counts=5349.0
#   DR1:
#     idx=7875 total_counts=10.0
#     idx=3118 total_counts=255.0
#   DSC3:
#     idx=8391 total_counts=191.0
#     idx=8389 total_counts=215.0
#   DTWD1:
#     idx=17351 total_counts=113.0
#     idx=911 total_counts=348.0
#   EAF2:
#     idx=16365 total_counts=278.0
#     idx=16578 total_counts=1171.0
#   ELK1:
#     idx=17312 total_counts=932.0
#     idx=10984 total_counts=659.0
#   FAAH:
#     idx=16393 total_counts=2569.0
#     idx=4126 total_counts=297.0
#   FBP2:
#     idx=13589 total_counts=1738.0
#     idx=5399 total_counts=89.0
#   FKBP6:
#     idx=3427 total_counts=7.0
#     idx=11111 total_counts=135.0
#   FMN2:
#     idx=8483 total_counts=15343.0
#     idx=15672 total_counts=4.0
#   GMPS:
#     idx=538 total_counts=2294.0
#     idx=1922 total_counts=3.0
#   GPT:
#     idx=1433 total_counts=121.0
#     idx=9546 total_counts=251.0
#   GPX6:
#     idx=14959 total_counts=111.0
#     idx=6160 total_counts=13.0
#   GRIK2:
#     idx=11869 total_counts=102531.0
#     idx=16635 total_counts=3616.0
#   GRIN1:
#     idx=6876 total_counts=3961.0
#     idx=1086 total_counts=33.0
#   GTF2A2:
#     idx=7355 total_counts=398.0
#     idx=9774 total_counts=855.0
#   GTF2F1:
#     idx=13714 total_counts=514.0
#     idx=13683 total_counts=34.0
#   HAT1:
#     idx=9899 total_counts=3580.0
#     idx=9912 total_counts=12024.0
#   HEG1:
#     idx=948 total_counts=2178.0
#     idx=930 total_counts=1671.0
#   HLF:
#     idx=2409 total_counts=234.0
#     idx=10955 total_counts=2318.0
#   HNRNPA2B1:
#     idx=2312 total_counts=15331.0
#     idx=6709 total_counts=21.0
#   HRH2:
#     idx=1240 total_counts=1244.0
#     idx=5748 total_counts=3363.0
#   HTRA3:
#     idx=5807 total_counts=101.0
#     idx=15150 total_counts=592.0
#   IGFLR1:
#     idx=11467 total_counts=14.0
#     idx=11327 total_counts=74.0
#   IMP3:
#     idx=16063 total_counts=4.0
#     idx=2280 total_counts=6651.0
#   IMP4:
#     idx=12577 total_counts=1224.0
#     idx=689 total_counts=84.0
#   INPP4A:
#     idx=3881 total_counts=440.0
#     idx=3857 total_counts=4817.0
#   KLHL41:
#     idx=9916 total_counts=33.0
#     idx=9906 total_counts=885.0
#   KPNA7:
#     idx=7236 total_counts=3749.0
#     idx=3365 total_counts=48.0
#   LGALS2:
#     idx=974 total_counts=14.0
#     idx=5346 total_counts=11.0
#   MADD:
#     idx=16045 total_counts=3002.0
#     idx=7717 total_counts=8743.0
#   MAGI1:
#     idx=15924 total_counts=20839.0
#     idx=9459 total_counts=360.0
#   MAGOHB:
#     idx=5119 total_counts=272.0
#     idx=7139 total_counts=14.0
#   MAL:
#     idx=5170 total_counts=8363.0
#     idx=4025 total_counts=58.0
#   MAST1:
#     idx=606 total_counts=10281.0
#     idx=16306 total_counts=9551.0
#   MED24:
#     idx=11088 total_counts=886.0
#     idx=7027 total_counts=68.0
#   MGA:
#     idx=6701 total_counts=2244.0
#     idx=11639 total_counts=7317.0
#   MPP7:
#     idx=3741 total_counts=641.0
#     idx=12137 total_counts=5341.0
#   MYT1:
#     idx=2949 total_counts=1593.0
#     idx=13028 total_counts=77.0
#   NBN:
#     idx=15929 total_counts=246.0
#     idx=2607 total_counts=1638.0
#   NOP9:
#     idx=12576 total_counts=49.0
#     idx=12572 total_counts=269.0
#   NOS1:
#     idx=4813 total_counts=794.0
#     idx=2002 total_counts=4.0
#   NPR3:
#     idx=16760 total_counts=646.0
#     idx=5004 total_counts=122.0
#   NRAP:
#     idx=1849 total_counts=188.0
#     idx=2042 total_counts=18.0
#   NRF1:
#     idx=11021 total_counts=174.0
#     idx=9378 total_counts=5284.0
#   NTN4:
#     idx=4445 total_counts=1020.0
#     idx=15130 total_counts=824.0
#   OPA1:
#     idx=423 total_counts=4840.0
#     idx=16145 total_counts=1379.0
#   OR5K4:
#     idx=9284 total_counts=9.0
#     idx=9287 total_counts=215.0
#   PAK3:
#     idx=10711 total_counts=16901.0
#     idx=10784 total_counts=6498.0
#   PGBD2:
#     idx=2962 total_counts=71.0
#     idx=6133 total_counts=2437.0
#   PKD2:
#     idx=15490 total_counts=2723.0
#     idx=14077 total_counts=256.0
#   PPAT:
#     idx=11010 total_counts=294.0
#     idx=5538 total_counts=1666.0
#   PRDX6:
#     idx=7572 total_counts=68.0
#     idx=8446 total_counts=141.0
#   PTMA:
#     idx=14770 total_counts=1376.0
#     idx=1255 total_counts=59.0
#   RAD1:
#     idx=10151 total_counts=1565.0
#     idx=5020 total_counts=57.0
#   RILP:
#     idx=10279 total_counts=5.0
#     idx=12316 total_counts=1940.0
#   ROR2:
#     idx=15182 total_counts=5256.0
#     idx=9753 total_counts=47124.0
#   RPF1:
#     idx=3178 total_counts=804.0
#     idx=843 total_counts=1026.0
#   RPL13:
#     idx=6804 total_counts=678.0
#     idx=4104 total_counts=368.0
#   RPL17:
#     idx=9152 total_counts=245.0
#     idx=11077 total_counts=610.0
#   RPL27A:
#     idx=8019 total_counts=542.0
#     idx=9214 total_counts=129.0
#   RPS12:
#     idx=9256 total_counts=302.0
#     idx=11400 total_counts=39.0
#   RPS16:
#     idx=6950 total_counts=5.0
#     idx=11418 total_counts=330.0
#   RPS23:
#     idx=16288 total_counts=22.0
#     idx=3027 total_counts=339.0
#   SAP130:
#     idx=636 total_counts=2270.0
#     idx=4078 total_counts=2715.0
#   SAT2:
#     idx=12347 total_counts=408.0
#     idx=10401 total_counts=112.0
#   SDS:
#     idx=3372 total_counts=1042.0
#     idx=4639 total_counts=170.0
#   SH3BGRL:
#     idx=3428 total_counts=19.0
#     idx=14273 total_counts=1076.0
#   SI:
#     idx=10592 total_counts=19.0
#     idx=315 total_counts=196.0
#   SLC4A5:
#     idx=3879 total_counts=154.0
#     idx=15698 total_counts=7177.0
#   SLIT1:
#     idx=2107 total_counts=12984.0
#     idx=1217 total_counts=24714.0
#   SNRPF:
#     idx=1800 total_counts=378.0
#     idx=4521 total_counts=137.0
#   SNRPG:
#     idx=6005 total_counts=356.0
#     idx=14340 total_counts=4.0
#   SOCS7:
#     idx=947 total_counts=270.0
#     idx=10990 total_counts=1661.0
#   SPCS2:
#     idx=12702 total_counts=1019.0
#     idx=12362 total_counts=4.0
#   SRA1:
#     idx=3069 total_counts=932.0
#     idx=11828 total_counts=425.0
#   STAR:
#     idx=5136 total_counts=26.0
#     idx=9244 total_counts=64.0
#   TKT:
#     idx=13167 total_counts=52.0
#     idx=13087 total_counts=3592.0
#   TPO:
#     idx=114 total_counts=166.0
#     idx=14750 total_counts=109.0
#   TPP1:
#     idx=12711 total_counts=558.0
#     idx=4112 total_counts=360.0
#   TRAPPC3:
#     idx=10258 total_counts=10.0
#     idx=7397 total_counts=741.0
#   VTI1B:
#     idx=1357 total_counts=113.0
#     idx=1597 total_counts=1072.0
#   ZNF543:
#     idx=14104 total_counts=1097.0
#     idx=13947 total_counts=64.0
# After droping duplicates: 24378 cells, 17303 genes
# hippocampus: 13634 cells, 17592 genes
# Index(['ZMYND10', 'AMIGO3', 'TNFSF10', 'NPRL2', 'GMPPB'], dtype='object')
#
# Duplicate genes found:
#   ACP1:
#     idx=10258 total_counts=417.0
#     idx=14890 total_counts=291.0
#   AKAP7:
#     idx=5473 total_counts=1223.0
#     idx=5452 total_counts=24.0
#   AMD1:
#     idx=16875 total_counts=2559.0
#     idx=14753 total_counts=15.0
#   AMN:
#     idx=1722 total_counts=333.0
#     idx=17351 total_counts=434.0
#   APPL2:
#     idx=12328 total_counts=4271.0
#     idx=4586 total_counts=849.0
#   AR:
#     idx=9472 total_counts=692.0
#     idx=15884 total_counts=548.0
#   ARG1:
#     idx=7437 total_counts=31.0
#     idx=5480 total_counts=705.0
#   ARID3C:
#     idx=1865 total_counts=202.0
#     idx=1894 total_counts=524.0
#   ASIP:
#     idx=12246 total_counts=12325.0
#     idx=14649 total_counts=67.0
#   ATL2:
#     idx=2539 total_counts=3717.0
#     idx=14018 total_counts=3.0
#   BNC1:
#     idx=8182 total_counts=10.0
#     idx=15667 total_counts=67500.0
#   BRCC3:
#     idx=12322 total_counts=862.0
#     idx=17444 total_counts=1836.0
#   BRF1:
#     idx=1776 total_counts=5922.0
#     idx=1753 total_counts=686.0
#   BRI3:
#     idx=3522 total_counts=350.0
#     idx=14942 total_counts=198.0
#   BRPF3:
#     idx=15109 total_counts=10.0
#     idx=6458 total_counts=1142.0
#   BTG1:
#     idx=8123 total_counts=3.0
#     idx=4525 total_counts=574.0
#   CAP1:
#     idx=7320 total_counts=1389.0
#     idx=10273 total_counts=95.0
#   CAST:
#     idx=16787 total_counts=243.0
#     idx=3001 total_counts=2757.0
#   CCR4:
#     idx=1219 total_counts=5424.0
#     idx=9930 total_counts=871.0
#   CCT2:
#     idx=3757 total_counts=3.0
#     idx=4554 total_counts=3521.0
#   CCT6B:
#     idx=15672 total_counts=173.0
#     idx=8695 total_counts=7.0
#   CDH1:
#     idx=4186 total_counts=17.0
#     idx=13857 total_counts=1899.0
#   CDH20:
#     idx=8666 total_counts=39.0
#     idx=10071 total_counts=15823.0
#   CDH7:
#     idx=10033 total_counts=677.0
#     idx=10032 total_counts=1036.0
#   CKLF:
#     idx=4185 total_counts=1810.0
#     idx=4420 total_counts=425.0
#   CSNK1E:
#     idx=5321 total_counts=1455.0
#     idx=15701 total_counts=12.0
#   CYCS:
#     idx=2244 total_counts=513.0
#     idx=566 total_counts=4.0
#   DCAF11:
#     idx=12693 total_counts=157.0
#     idx=12698 total_counts=619.0
#   DCUN1D4:
#     idx=5605 total_counts=5510.0
#     idx=4903 total_counts=46.0
#   DIO1:
#     idx=2866 total_counts=1188.0
#     idx=17245 total_counts=382.0
#   DLC1:
#     idx=8301 total_counts=751.0
#     idx=14392 total_counts=5831.0
#   DLG3:
#     idx=11043 total_counts=1725.0
#     idx=16317 total_counts=5351.0
#   DR1:
#     idx=3149 total_counts=457.0
#     idx=7944 total_counts=13.0
#   DSC3:
#     idx=8457 total_counts=172.0
#     idx=8459 total_counts=207.0
#   DTWD1:
#     idx=17525 total_counts=111.0
#     idx=923 total_counts=548.0
#   EAF2:
#     idx=16539 total_counts=570.0
#     idx=16755 total_counts=1564.0
#   ELK1:
#     idx=17488 total_counts=931.0
#     idx=11070 total_counts=497.0
#   FAAH:
#     idx=16567 total_counts=3193.0
#     idx=4164 total_counts=430.0
#   FBP2:
#     idx=13720 total_counts=2411.0
#     idx=5442 total_counts=119.0
#   FKBP6:
#     idx=11195 total_counts=140.0
#     idx=3458 total_counts=11.0
#   FMN2:
#     idx=15828 total_counts=3.0
#     idx=8555 total_counts=13557.0
#   GMPS:
#     idx=1947 total_counts=3.0
#     idx=547 total_counts=2753.0
#   GPT:
#     idx=9610 total_counts=213.0
#     idx=1450 total_counts=306.0
#   GPX6:
#     idx=6216 total_counts=11.0
#     idx=15098 total_counts=132.0
#   GRIK2:
#     idx=11971 total_counts=116445.0
#     idx=16810 total_counts=3728.0
#   GRIN1:
#     idx=6936 total_counts=4419.0
#     idx=1094 total_counts=41.0
#   GTF2A2:
#     idx=9845 total_counts=1364.0
#     idx=7421 total_counts=366.0
#   GTF2F1:
#     idx=13846 total_counts=645.0
#     idx=13815 total_counts=84.0
#   HAT1:
#     idx=9976 total_counts=3910.0
#     idx=9989 total_counts=9951.0
#   HEG1:
#     idx=960 total_counts=2400.0
#     idx=942 total_counts=2212.0
#   HLF:
#     idx=2438 total_counts=402.0
#     idx=11040 total_counts=2179.0
#   HNRNPA2B1:
#     idx=2339 total_counts=18692.0
#     idx=6768 total_counts=13.0
#   HRH2:
#     idx=1248 total_counts=1689.0
#     idx=5797 total_counts=4090.0
#   HTRA3:
#     idx=5859 total_counts=143.0
#     idx=15293 total_counts=622.0
#   IGFLR1:
#     idx=11417 total_counts=145.0
#     idx=11558 total_counts=59.0
#   IMP3:
#     idx=2307 total_counts=6876.0
#     idx=16227 total_counts=21.0
#   IMP4:
#     idx=702 total_counts=262.0
#     idx=12690 total_counts=1237.0
#   INPP4A:
#     idx=3918 total_counts=530.0
#     idx=3894 total_counts=4967.0
#   KLHL41:
#     idx=9993 total_counts=67.0
#     idx=9983 total_counts=1009.0
#   KPNA7:
#     idx=7302 total_counts=3557.0
#     idx=3395 total_counts=80.0
#   LGALS2:
#     idx=986 total_counts=11.0
#     idx=5389 total_counts=13.0
#   MADD:
#     idx=7786 total_counts=8368.0
#     idx=16209 total_counts=3693.0
#   MAGI1:
#     idx=9525 total_counts=561.0
#     idx=16086 total_counts=23050.0
#   MAGOHB:
#     idx=5161 total_counts=532.0
#     idx=7202 total_counts=6.0
#   MAL:
#     idx=5212 total_counts=9848.0
#     idx=4062 total_counts=59.0
#   MAST1:
#     idx=618 total_counts=12104.0
#     idx=16478 total_counts=8778.0
#   MED24:
#     idx=11172 total_counts=1401.0
#     idx=7088 total_counts=102.0
#   MGA:
#     idx=11737 total_counts=7476.0
#     idx=6760 total_counts=2578.0
#   MPP7:
#     idx=3775 total_counts=791.0
#     idx=12242 total_counts=5671.0
#   MYT1:
#     idx=13156 total_counts=198.0
#     idx=2979 total_counts=2797.0
#   NBN:
#     idx=2638 total_counts=2341.0
#     idx=16091 total_counts=205.0
#   NOP9:
#     idx=12689 total_counts=88.0
#     idx=12685 total_counts=377.0
#   NOS1:
#     idx=4856 total_counts=867.0
#     idx=2028 total_counts=3.0
#   NPR3:
#     idx=16936 total_counts=827.0
#     idx=5045 total_counts=115.0
#   NRAP:
#     idx=1873 total_counts=228.0
#     idx=2067 total_counts=53.0
#   NRF1:
#     idx=9443 total_counts=6824.0
#     idx=11107 total_counts=207.0
#   NTN4:
#     idx=15273 total_counts=1873.0
#     idx=4486 total_counts=1537.0
#   OPA1:
#     idx=429 total_counts=5711.0
#     idx=16310 total_counts=1478.0
#   OR5K4:
#     idx=9349 total_counts=4.0
#     idx=9352 total_counts=193.0
#   PAK3:
#     idx=10863 total_counts=6108.0
#     idx=10791 total_counts=17336.0
#   PGBD2:
#     idx=6189 total_counts=2248.0
#     idx=2992 total_counts=110.0
#   PKD2:
#     idx=14218 total_counts=458.0
#     idx=15637 total_counts=3016.0
#   PPAT:
#     idx=5583 total_counts=1755.0
#     idx=11096 total_counts=518.0
#   PRDX6:
#     idx=7642 total_counts=179.0
#     idx=8515 total_counts=300.0
#   PTMA:
#     idx=14906 total_counts=5951.0
#     idx=1264 total_counts=27.0
#   RAD1:
#     idx=10232 total_counts=1923.0
#     idx=5061 total_counts=89.0
#   RILP:
#     idx=10361 total_counts=8.0
#     idx=12429 total_counts=1597.0
#   ROR2:
#     idx=9823 total_counts=51008.0
#     idx=15325 total_counts=3398.0
#   RPF1:
#     idx=855 total_counts=1051.0
#     idx=3209 total_counts=844.0
#   RPL13:
#     idx=4144 total_counts=2121.0
#     idx=6860 total_counts=1032.0
#   RPL17:
#     idx=11162 total_counts=2961.0
#     idx=9221 total_counts=793.0
#   RPL27A:
#     idx=8090 total_counts=2231.0
#     idx=9285 total_counts=128.0
#   RPS12:
#     idx=11490 total_counts=89.0
#     idx=9322 total_counts=978.0
#   RPS16:
#     idx=7011 total_counts=13.0
#     idx=11509 total_counts=1611.0
#   RPS23:
#     idx=16461 total_counts=15.0
#     idx=3057 total_counts=790.0
#   SAP130:
#     idx=648 total_counts=2158.0
#     idx=4115 total_counts=3632.0
#   SAT2:
#     idx=10483 total_counts=97.0
#     idx=12459 total_counts=672.0
#   SDS:
#     idx=4684 total_counts=175.0
#     idx=3402 total_counts=1007.0
#   SH3BGRL:
#     idx=14414 total_counts=1274.0
#     idx=3459 total_counts=14.0
#   SI:
#     idx=10672 total_counts=34.0
#     idx=318 total_counts=323.0
#   SLC4A5:
#     idx=3916 total_counts=134.0
#     idx=15854 total_counts=8624.0
#   SLIT1:
#     idx=1225 total_counts=32368.0
#     idx=2133 total_counts=12539.0
#   SNRPF:
#     idx=4563 total_counts=466.0
#     idx=1822 total_counts=571.0
#   SOCS7:
#     idx=959 total_counts=366.0
#     idx=11075 total_counts=1883.0
#   SRA1:
#     idx=11929 total_counts=1210.0
#     idx=3098 total_counts=907.0
#   STAR:
#     idx=5178 total_counts=36.0
#     idx=9313 total_counts=86.0
#   TKT:
#     idx=13215 total_counts=3966.0
#     idx=13298 total_counts=112.0
#   TPO:
#     idx=14888 total_counts=155.0
#     idx=115 total_counts=49.0
#   TPP1:
#     idx=4152 total_counts=429.0
#     idx=12828 total_counts=566.0
#   TRAPPC3:
#     idx=10340 total_counts=12.0
#     idx=7465 total_counts=1007.0
#   VTI1B:
#     idx=1368 total_counts=128.0
#     idx=1615 total_counts=1238.0
#   ZNF543:
#     idx=14245 total_counts=1288.0
#     idx=14086 total_counts=101.0
# After droping duplicates: 13634 cells, 17480 genes
# midbrain: 8070 cells, 13915 genes
# Index(['ZMYND10', 'TNFSF10', 'NPRL2', 'GMPPB', 'NCEH1'], dtype='object')
#
# Duplicate genes found:
#   ACP1:
#     idx=8175 total_counts=210.0
#     idx=11841 total_counts=5.0
#   AMN:
#     idx=13745 total_counts=24.0
#     idx=1362 total_counts=25.0
#   APPL2:
#     idx=3663 total_counts=107.0
#     idx=9827 total_counts=757.0
#   AR:
#     idx=7562 total_counts=105.0
#     idx=12603 total_counts=46.0
#   ARG1:
#     idx=4388 total_counts=5.0
#     idx=5945 total_counts=8.0
#   ARID3C:
#     idx=1494 total_counts=43.0
#     idx=1477 total_counts=44.0
#   BRCC3:
#     idx=13819 total_counts=99.0
#     idx=9823 total_counts=11.0
#   BRF1:
#     idx=1407 total_counts=206.0
#     idx=1388 total_counts=115.0
#   CAST:
#     idx=13302 total_counts=14.0
#     idx=2385 total_counts=282.0
#   CCR4:
#     idx=7915 total_counts=3.0
#     idx=958 total_counts=199.0
#   CCT2:
#     idx=2998 total_counts=4.0
#     idx=3639 total_counts=479.0
#   CDH7:
#     idx=7996 total_counts=26.0
#     idx=7995 total_counts=167.0
#   CKLF:
#     idx=3343 total_counts=169.0
#     idx=3533 total_counts=12.0
#   DCAF11:
#     idx=10107 total_counts=14.0
#     idx=10112 total_counts=131.0
#   DIO1:
#     idx=13661 total_counts=4.0
#     idx=2276 total_counts=45.0
#   DLC1:
#     idx=6636 total_counts=22.0
#     idx=11434 total_counts=494.0
#   DLG3:
#     idx=8803 total_counts=123.0
#     idx=12950 total_counts=288.0
#   DSC3:
#     idx=6771 total_counts=4.0
#     idx=6769 total_counts=7.0
#   EAF2:
#     idx=13279 total_counts=32.0
#     idx=13108 total_counts=115.0
#   ELK1:
#     idx=13852 total_counts=50.0
#     idx=8822 total_counts=8.0
#   FAAH:
#     idx=13130 total_counts=94.0
#     idx=3324 total_counts=24.0
#   FBP2:
#     idx=4358 total_counts=7.0
#     idx=10892 total_counts=294.0
#   GPT:
#     idx=7667 total_counts=20.0
#     idx=1135 total_counts=30.0
#   GRIK2:
#     idx=9547 total_counts=6195.0
#     idx=13322 total_counts=106.0
#   GTF2F1:
#     idx=11006 total_counts=129.0
#     idx=10980 total_counts=5.0
#   HAT1:
#     idx=7963 total_counts=100.0
#     idx=7952 total_counts=80.0
#   HEG1:
#     idx=739 total_counts=90.0
#     idx=756 total_counts=69.0
#   HLF:
#     idx=8801 total_counts=157.0
#     idx=1930 total_counts=128.0
#   HNRNPA2B1:
#     idx=1849 total_counts=894.0
#     idx=5402 total_counts=4.0
#   HRH2:
#     idx=984 total_counts=56.0
#     idx=4634 total_counts=243.0
#   HTRA3:
#     idx=12147 total_counts=117.0
#     idx=4682 total_counts=43.0
#   IMP4:
#     idx=10104 total_counts=82.0
#     idx=549 total_counts=69.0
#   INPP4A:
#     idx=3122 total_counts=101.0
#     idx=3105 total_counts=479.0
#   KLHL41:
#     idx=7966 total_counts=14.0
#     idx=7958 total_counts=51.0
#   MADD:
#     idx=12862 total_counts=284.0
#     idx=6225 total_counts=583.0
#   MAGI1:
#     idx=12766 total_counts=1332.0
#     idx=7598 total_counts=78.0
#   MAL:
#     idx=4176 total_counts=566.0
#     idx=3236 total_counts=14.0
#   MAST1:
#     idx=486 total_counts=421.0
#     idx=13062 total_counts=1000.0
#   MED24:
#     idx=8914 total_counts=226.0
#     idx=5663 total_counts=36.0
#   MGA:
#     idx=5395 total_counts=112.0
#     idx=9352 total_counts=373.0
#   MPP7:
#     idx=3014 total_counts=29.0
#     idx=9760 total_counts=262.0
#   MYT1:
#     idx=10455 total_counts=7.0
#     idx=2373 total_counts=143.0
#   NBN:
#     idx=2092 total_counts=94.0
#     idx=12770 total_counts=14.0
#   NOP9:
#     idx=10101 total_counts=63.0
#     idx=10103 total_counts=11.0
#   NPR3:
#     idx=13425 total_counts=44.0
#     idx=4045 total_counts=14.0
#   NRF1:
#     idx=8858 total_counts=3.0
#     idx=7542 total_counts=441.0
#   NTN4:
#     idx=12132 total_counts=413.0
#     idx=3583 total_counts=136.0
#   OPA1:
#     idx=347 total_counts=272.0
#     idx=12946 total_counts=107.0
#   PAK3:
#     idx=8595 total_counts=921.0
#     idx=8651 total_counts=436.0
#   PKD2:
#     idx=12419 total_counts=158.0
#     idx=11308 total_counts=19.0
#   PPAT:
#     idx=8847 total_counts=58.0
#     idx=4470 total_counts=99.0
#   PRDX6:
#     idx=6819 total_counts=125.0
#     idx=6106 total_counts=72.0
#   RAD1:
#     idx=8154 total_counts=142.0
#     idx=4055 total_counts=3.0
#   RHO:
#     idx=12406 total_counts=3.0
#     idx=6075 total_counts=14.0
#   ROR2:
#     idx=12172 total_counts=159.0
#     idx=7822 total_counts=2985.0
#   RPF1:
#     idx=2550 total_counts=85.0
#     idx=665 total_counts=27.0
#   RPL12:
#     idx=548 total_counts=5.0
#     idx=5749 total_counts=571.0
#   RPL13:
#     idx=5479 total_counts=127.0
#     idx=3305 total_counts=761.0
#   RPL17:
#     idx=7374 total_counts=663.0
#     idx=8905 total_counts=1047.0
#   RPL27A:
#     idx=6466 total_counts=965.0
#     idx=7425 total_counts=4.0
#   RPS12:
#     idx=7456 total_counts=707.0
#     idx=9159 total_counts=24.0
#   RPS23:
#     idx=2428 total_counts=890.0
#     idx=13050 total_counts=3.0
#   SAP130:
#     idx=506 total_counts=145.0
#     idx=3281 total_counts=167.0
#   SAT2:
#     idx=8342 total_counts=29.0
#     idx=9927 total_counts=248.0
#   SDS:
#     idx=2710 total_counts=101.0
#     idx=3739 total_counts=5.0
#   SLC4A5:
#     idx=12576 total_counts=642.0
#     idx=3121 total_counts=29.0
#   SLIT1:
#     idx=962 total_counts=493.0
#     idx=1682 total_counts=488.0
#   SNRPF:
#     idx=3648 total_counts=211.0
#     idx=1444 total_counts=5.0
#   SOCS7:
#     idx=755 total_counts=15.0
#     idx=8827 total_counts=167.0
#   SRA1:
#     idx=2461 total_counts=58.0
#     idx=9514 total_counts=235.0
#   TKT:
#     idx=10505 total_counts=658.0
#     idx=10560 total_counts=7.0
#   TPP1:
#     idx=10205 total_counts=95.0
#     idx=3313 total_counts=42.0
#   ZNF543:
#     idx=11196 total_counts=14.0
#     idx=11329 total_counts=79.0
# After droping duplicates: 8070 cells, 13842 genes

# %%
filtered_adult_datasets[0]
# Out:
# AnnData object with n_obs × n_vars = 4665 × 13342
#     obs: 'Tissue', 'TotalUMIs', 'organism_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'assay_ontology_term_id', 'sex_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'suspension_type', 'dissection', 'total_UMIs', 'sample_id', 'cluster_id', 'roi', 'dataset_source', 'species', 'region', 'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'stage'
#     var: 'Chromosome', 'End', 'Gene', 'Start', 'Strand', 'human_gene_name', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'global_name'
#     uns: 'batch_condition', 'schema_version', 'title'

# %%
filtered_nmr_datas[0]
# Out:
# AnnData object with n_obs × n_vars = 24378 × 17303
#     obs: 'species', 'sample', 'tissue', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts', 'qc_composite', 'qc_label', 'sample_id', 'replicate'
#     var: 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'global_name', 'original_names'

# %% [markdown]
# ## Merge datasets from human and nmr per region

# %% [markdown]
# ### only choose important columns to keep from obs

# %%
filtered_nmr_datas[0].obs[['species', 'sample', 'tissue', 'n_genes_by_counts',
       'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts',
       'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes',
       'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes',
       'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt',
       'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo',
       'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb',
       'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts',
       'qc_composite', 'qc_label', 'sample_id', 'replicate']]
# Out:
#                         species sample           tissue  n_genes_by_counts  \
# AAACCCAAGAAGCGAA-1-NMR1     nmr   NMR1  cerebral cortex               1559
# AAACCCAAGGAGGCAG-1-NMR1     nmr   NMR1  cerebral cortex               1312
# AAACCCACAAATCAAG-1-NMR1     nmr   NMR1  cerebral cortex                491
# AAACCCACAGTCTACA-1-NMR1     nmr   NMR1  cerebral cortex               1841
# AAACCCAGTACGTAGG-1-NMR1     nmr   NMR1  cerebral cortex                478
# ...                         ...    ...              ...                ...
# TTTGTTGCACTGAATC-1-NMR2     nmr   NMR2  cerebral cortex                189
# TTTGTTGGTCCCTCAT-1-NMR2     nmr   NMR2  cerebral cortex               1719
# TTTGTTGGTTCGGCTG-1-NMR2     nmr   NMR2  cerebral cortex                243
# TTTGTTGGTTCTCGCT-1-NMR2     nmr   NMR2  cerebral cortex                773
# TTTGTTGTCCGCTTAC-1-NMR2     nmr   NMR2  cerebral cortex                378
#
#                          log1p_n_genes_by_counts  total_counts  \
# AAACCCAAGAAGCGAA-1-NMR1                 7.352441        2298.0
# AAACCCAAGGAGGCAG-1-NMR1                 7.180070        1777.0
# AAACCCACAAATCAAG-1-NMR1                 6.198479         679.0
# AAACCCACAGTCTACA-1-NMR1                 7.518607        3369.0
# AAACCCAGTACGTAGG-1-NMR1                 6.171701         710.0
# ...                                          ...           ...
# TTTGTTGCACTGAATC-1-NMR2                 5.247024         282.0
# TTTGTTGGTCCCTCAT-1-NMR2                 7.450080        3030.0
# TTTGTTGGTTCGGCTG-1-NMR2                 5.497168         447.0
# TTTGTTGGTTCTCGCT-1-NMR2                 6.651572        1431.0
# TTTGTTGTCCGCTTAC-1-NMR2                 5.937536         642.0
#
#                          log1p_total_counts  pct_counts_in_top_50_genes  \
# AAACCCAAGAAGCGAA-1-NMR1            7.740230                   14.882507
# AAACCCAAGGAGGCAG-1-NMR1            7.483244                   14.350028
# AAACCCACAAATCAAG-1-NMR1            6.522093                   29.602356
# AAACCCACAGTCTACA-1-NMR1            8.122668                   19.709112
# AAACCCAGTACGTAGG-1-NMR1            6.566672                   32.535211
# ...                                     ...                         ...
# TTTGTTGCACTGAATC-1-NMR2            5.645447                   48.936170
# TTTGTTGGTCCCTCAT-1-NMR2            8.016648                   19.042904
# TTTGTTGGTTCGGCTG-1-NMR2            6.104793                   52.796421
# TTTGTTGGTTCTCGCT-1-NMR2            7.266827                   28.721174
# TTTGTTGTCCGCTTAC-1-NMR2            6.466145                   38.161994
#
#                          pct_counts_in_top_100_genes  \
# AAACCCAAGAAGCGAA-1-NMR1                    22.062663
# AAACCCAAGGAGGCAG-1-NMR1                    21.890827
# AAACCCACAAATCAAG-1-NMR1                    42.415317
# AAACCCACAGTCTACA-1-NMR1                    27.634313
# AAACCCAGTACGTAGG-1-NMR1                    46.760563
# ...                                              ...
# TTTGTTGCACTGAATC-1-NMR2                    68.439716
# TTTGTTGGTCCCTCAT-1-NMR2                    27.689769
# TTTGTTGGTTCGGCTG-1-NMR2                    68.008949
# TTTGTTGGTTCTCGCT-1-NMR2                    40.880503
# TTTGTTGTCCGCTTAC-1-NMR2                    53.894081
#
#                          pct_counts_in_top_200_genes  ...  \
# AAACCCAAGAAGCGAA-1-NMR1                    32.245431  ...
# AAACCCAAGGAGGCAG-1-NMR1                    33.145751  ...
# AAACCCACAAATCAAG-1-NMR1                    57.142857  ...
# AAACCCACAGTCTACA-1-NMR1                    38.171564  ...
# AAACCCAGTACGTAGG-1-NMR1                    60.845070  ...
# ...                                              ...  ...
# TTTGTTGCACTGAATC-1-NMR2                   100.000000  ...
# TTTGTTGGTCCCTCAT-1-NMR2                    38.184818  ...
# TTTGTTGGTTCGGCTG-1-NMR2                    90.380313  ...
# TTTGTTGGTTCTCGCT-1-NMR2                    56.254368  ...
# TTTGTTGTCCGCTTAC-1-NMR2                    72.274143  ...
#
#                          log1p_total_counts_hb  pct_counts_hb  \
# AAACCCAAGAAGCGAA-1-NMR1                    0.0            0.0
# AAACCCAAGGAGGCAG-1-NMR1                    0.0            0.0
# AAACCCACAAATCAAG-1-NMR1                    0.0            0.0
# AAACCCACAGTCTACA-1-NMR1                    0.0            0.0
# AAACCCAGTACGTAGG-1-NMR1                    0.0            0.0
# ...                                        ...            ...
# TTTGTTGCACTGAATC-1-NMR2                    0.0            0.0
# TTTGTTGGTCCCTCAT-1-NMR2                    0.0            0.0
# TTTGTTGGTTCGGCTG-1-NMR2                    0.0            0.0
# TTTGTTGGTTCTCGCT-1-NMR2                    0.0            0.0
# TTTGTTGTCCGCTTAC-1-NMR2                    0.0            0.0
#
#                          total_counts_tf  log1p_total_counts_tf  \
# AAACCCAAGAAGCGAA-1-NMR1             23.0               3.178054
# AAACCCAAGGAGGCAG-1-NMR1             24.0               3.218876
# AAACCCACAAATCAAG-1-NMR1              2.0               1.098612
# AAACCCACAGTCTACA-1-NMR1             36.0               3.610918
# AAACCCAGTACGTAGG-1-NMR1              8.0               2.197225
# ...                                  ...                    ...
# TTTGTTGCACTGAATC-1-NMR2              8.0               2.197225
# TTTGTTGGTCCCTCAT-1-NMR2             33.0               3.526361
# TTTGTTGGTTCGGCTG-1-NMR2              3.0               1.386294
# TTTGTTGGTTCTCGCT-1-NMR2             29.0               3.401197
# TTTGTTGTCCGCTTAC-1-NMR2             14.0               2.708050
#
#                          pct_counts_tf  n_counts  qc_composite    qc_label  \
# AAACCCAAGAAGCGAA-1-NMR1       1.000870    2298.0           8.0  acceptable
# AAACCCAAGGAGGCAG-1-NMR1       1.350591    1777.0          60.0  acceptable
# AAACCCACAAATCAAG-1-NMR1       0.294551     679.0          92.0  acceptable
# AAACCCACAGTCTACA-1-NMR1       1.068566    3369.0           1.0  acceptable
# AAACCCAGTACGTAGG-1-NMR1       1.126761     710.0          92.0  acceptable
# ...                                ...       ...           ...         ...
# TTTGTTGCACTGAATC-1-NMR2       2.836879     282.0          25.5  acceptable
# TTTGTTGGTCCCTCAT-1-NMR2       1.089109    3030.0          59.0  acceptable
# TTTGTTGGTTCGGCTG-1-NMR2       0.671141     447.0          59.0  acceptable
# TTTGTTGGTTCTCGCT-1-NMR2       2.026555    1431.0          27.5  acceptable
# TTTGTTGTCCGCTTAC-1-NMR2       2.180685     642.0          27.5  acceptable
#
#                          sample_id  replicate
# AAACCCAAGAAGCGAA-1-NMR1          1          1
# AAACCCAAGGAGGCAG-1-NMR1          1          1
# AAACCCACAAATCAAG-1-NMR1          1          1
# AAACCCACAGTCTACA-1-NMR1          1          1
# AAACCCAGTACGTAGG-1-NMR1          1          1
# ...                            ...        ...
# TTTGTTGCACTGAATC-1-NMR2          2          2
# TTTGTTGGTCCCTCAT-1-NMR2          2          2
# TTTGTTGGTTCGGCTG-1-NMR2          2          2
# TTTGTTGGTTCTCGCT-1-NMR2          2          2
# TTTGTTGTCCGCTTAC-1-NMR2          2          2
#
# [24378 rows x 28 columns]

# %%
# Merge (outer) datasets from the same region
outer_datasets = []
for human_adult_adata, human_dev_adata, nmr_adata in zip(filtered_adult_datasets,filtered_dev_datasets, filtered_nmr_datas):
    human_dev_adata.obs = human_dev_adata.obs[['Age', 'CellClass', 'Region', 'Subregion',
       'donor_id', 'suspension_type', 'dissection', 'cell_cycle_score',
       'total_genes', 'total_UMIs', 'sample_id', 'cluster_id',
       'dataset_source', 'stage', 'species', 'region', 'Major Field', 'Supercluster',
       'Specific', 'Top Enriched Genes', 'n_genes_by_counts',
       'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts',
       'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes',
       'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes',
       'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt',
       'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo']]
    human_adult_adata.obs = human_adult_adata.obs[['donor_id', 'suspension_type',
       'dissection', 'total_UMIs', 'sample_id', 'cluster_id', 'roi',
       'dataset_source', 'stage', 'species', 'region', 'Major Field', 'Supercluster',
       'Specific', 'Top Enriched Genes', 'n_genes_by_counts',
       'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts',
       'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes',
       'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes',
       'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt',
       'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo',
       ]]
    nmr_adata.obs['donor_id'] = ['ratopin'+ str(i) for i in nmr_adata.obs['replicate']]
    nmr_adata.obs = nmr_adata.obs[['species', 'sample', 'tissue', 'donor_id',  'n_genes_by_counts',
       'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts',
       'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes',
       'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes',
       'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt',
       'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo',
       'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb',
       'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts',
       'qc_composite', 'qc_label']]
    nmr_adata.obs.rename(columns={'sample':'sample_id','tissue':'region'}, inplace=True)
    
    combined_adata = nmr_adata.concatenate([human_adult_adata,human_dev_adata], join='outer', batch_key='dataset', batch_categories=["nmr", 'human_adult','human_dev'],  index_unique=None, fill_value=0)
    outer_datasets.append(combined_adata)
    print("Merged AnnData (outer):", combined_adata.shape)
# Out:
# Merged AnnData (outer): (31043, 19066)
# Merged AnnData (outer): (18865, 19148)
# Merged AnnData (outer): (13145, 16856)

# %%
outer_datasets
# Out:
# [AnnData object with n_obs × n_vars = 31043 × 19066
#      obs: 'species', 'sample_id', 'region', 'donor_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts', 'qc_composite', 'qc_label', 'suspension_type', 'dissection', 'total_UMIs', 'cluster_id', 'roi', 'dataset_source', 'stage', 'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes', 'Age', 'CellClass', 'Region', 'Subregion', 'cell_cycle_score', 'total_genes', 'dataset'
#      var: 'mt-human_adult', 'ribo-human_adult', 'n_cells_by_counts-human_adult', 'mean_counts-human_adult', 'log1p_mean_counts-human_adult', 'pct_dropout_by_counts-human_adult', 'total_counts-human_adult', 'log1p_total_counts-human_adult', 'n_cells-human_adult', 'global_name-human_adult', 'Chromosome-human_adult', 'End-human_adult', 'Gene-human_adult', 'Start-human_adult', 'Strand-human_adult', 'human_gene_name-human_adult', 'mt-human_dev', 'ribo-human_dev', 'n_cells_by_counts-human_dev', 'mean_counts-human_dev', 'log1p_mean_counts-human_dev', 'pct_dropout_by_counts-human_dev', 'total_counts-human_dev', 'log1p_total_counts-human_dev', 'n_cells-human_dev', 'global_name-human_dev', 'Chromosome-human_dev', 'End-human_dev', 'Gene-human_dev', 'Start-human_dev', 'human_gene_name-human_dev', 'GeneTotalUMIs-human_dev', 'mt-nmr', 'ribo-nmr', 'n_cells_by_counts-nmr', 'mean_counts-nmr', 'log1p_mean_counts-nmr', 'pct_dropout_by_counts-nmr', 'total_counts-nmr', 'log1p_total_counts-nmr', 'n_cells-nmr', 'global_name-nmr', 'original_names-nmr'
#      obsm: 'Factors', 'X_Embedding',
#  AnnData object with n_obs × n_vars = 18865 × 19148
#      obs: 'species', 'sample_id', 'region', 'donor_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts', 'qc_composite', 'qc_label', 'suspension_type', 'dissection', 'total_UMIs', 'cluster_id', 'roi', 'dataset_source', 'stage', 'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes', 'Age', 'CellClass', 'Region', 'Subregion', 'cell_cycle_score', 'total_genes', 'dataset'
#      var: 'mt-human_adult', 'ribo-human_adult', 'n_cells_by_counts-human_adult', 'mean_counts-human_adult', 'log1p_mean_counts-human_adult', 'pct_dropout_by_counts-human_adult', 'total_counts-human_adult', 'log1p_total_counts-human_adult', 'n_cells-human_adult', 'global_name-human_adult', 'Chromosome-human_adult', 'End-human_adult', 'Gene-human_adult', 'Start-human_adult', 'Strand-human_adult', 'human_gene_name-human_adult', 'mt-human_dev', 'ribo-human_dev', 'n_cells_by_counts-human_dev', 'mean_counts-human_dev', 'log1p_mean_counts-human_dev', 'pct_dropout_by_counts-human_dev', 'total_counts-human_dev', 'log1p_total_counts-human_dev', 'n_cells-human_dev', 'global_name-human_dev', 'Chromosome-human_dev', 'End-human_dev', 'Gene-human_dev', 'Start-human_dev', 'human_gene_name-human_dev', 'GeneTotalUMIs-human_dev', 'mt-nmr', 'ribo-nmr', 'n_cells_by_counts-nmr', 'mean_counts-nmr', 'log1p_mean_counts-nmr', 'pct_dropout_by_counts-nmr', 'total_counts-nmr', 'log1p_total_counts-nmr', 'n_cells-nmr', 'global_name-nmr', 'original_names-nmr'
#      obsm: 'Factors', 'X_Embedding',
#  AnnData object with n_obs × n_vars = 13145 × 16856
#      obs: 'species', 'sample_id', 'region', 'donor_id', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts', 'qc_composite', 'qc_label', 'suspension_type', 'dissection', 'total_UMIs', 'cluster_id', 'roi', 'dataset_source', 'stage', 'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes', 'Age', 'CellClass', 'Region', 'Subregion', 'cell_cycle_score', 'total_genes', 'dataset'
#      var: 'mt-human_adult', 'ribo-human_adult', 'n_cells_by_counts-human_adult', 'mean_counts-human_adult', 'log1p_mean_counts-human_adult', 'pct_dropout_by_counts-human_adult', 'total_counts-human_adult', 'log1p_total_counts-human_adult', 'n_cells-human_adult', 'global_name-human_adult', 'Chromosome-human_adult', 'End-human_adult', 'Gene-human_adult', 'Start-human_adult', 'Strand-human_adult', 'human_gene_name-human_adult', 'mt-human_dev', 'ribo-human_dev', 'n_cells_by_counts-human_dev', 'mean_counts-human_dev', 'log1p_mean_counts-human_dev', 'pct_dropout_by_counts-human_dev', 'total_counts-human_dev', 'log1p_total_counts-human_dev', 'n_cells-human_dev', 'global_name-human_dev', 'Chromosome-human_dev', 'End-human_dev', 'Gene-human_dev', 'Start-human_dev', 'human_gene_name-human_dev', 'GeneTotalUMIs-human_dev', 'mt-nmr', 'ribo-nmr', 'n_cells_by_counts-nmr', 'mean_counts-nmr', 'log1p_mean_counts-nmr', 'pct_dropout_by_counts-nmr', 'total_counts-nmr', 'log1p_total_counts-nmr', 'n_cells-nmr', 'global_name-nmr', 'original_names-nmr'
#      obsm: 'Factors', 'X_Embedding']

# %%
for dataset in outer_datasets:
    print(dataset.obs['dataset'].value_counts())
# Out:
# dataset
# nmr            24378
# human_adult     4665
# human_dev       2000
# Name: count, dtype: int64
# dataset
# nmr            13634
# human_adult     4572
# human_dev        659
# Name: count, dtype: int64
# dataset
# nmr            8070
# human_adult    4128
# human_dev       947
# Name: count, dtype: int64

# %%
outer_datasets[0].obs.columns
# Out:
# Index(['species', 'sample_id', 'region', 'donor_id', 'n_genes_by_counts',
#        'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts',
#        'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes',
#        'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes',
#        'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt',
#        'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo',
#        'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb',
#        'total_counts_tf', 'log1p_total_counts_tf', 'pct_counts_tf', 'n_counts',
#        'qc_composite', 'qc_label', 'suspension_type', 'dissection',
#        'total_UMIs', 'cluster_id', 'roi', 'dataset_source', 'stage',
#        'Major Field', 'Supercluster', 'Specific', 'Top Enriched Genes', 'Age',
#        'CellClass', 'Region', 'Subregion', 'cell_cycle_score', 'total_genes',
#        'dataset'],
#       dtype='object')

# %%
outer_datasets[0].obs
# Out:
#                           species sample_id           region  donor_id  \
# AAACCCAAGAAGCGAA-1-NMR1       nmr      NMR1  cerebral cortex  ratopin1
# AAACCCAAGGAGGCAG-1-NMR1       nmr      NMR1  cerebral cortex  ratopin1
# AAACCCACAAATCAAG-1-NMR1       nmr      NMR1  cerebral cortex  ratopin1
# AAACCCACAGTCTACA-1-NMR1       nmr      NMR1  cerebral cortex  ratopin1
# AAACCCAGTACGTAGG-1-NMR1       nmr      NMR1  cerebral cortex  ratopin1
# ...                           ...       ...              ...       ...
# 10X257_2:TCATACTCAGCACAGA   human  10X257_2  cerebral cortex   XDD:385
# 10X257_2:TCCCATGTCGATTCCC   human  10X257_2  cerebral cortex   XDD:385
# 10X257_4:ATTCCATCAGTGGTGA   human  10X257_4  cerebral cortex   XDD:385
# 10X257_5:ATGCCTCAGGTCATTC   human  10X257_5  cerebral cortex   XDD:385
# 10X257_6:GATCATGAGACCATGG   human  10X257_6  cerebral cortex   XDD:385
#
#                            n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACCCAAGAAGCGAA-1-NMR1                 1559                 7.352441
# AAACCCAAGGAGGCAG-1-NMR1                 1312                 7.180070
# AAACCCACAAATCAAG-1-NMR1                  491                 6.198479
# AAACCCACAGTCTACA-1-NMR1                 1841                 7.518607
# AAACCCAGTACGTAGG-1-NMR1                  478                 6.171701
# ...                                      ...                      ...
# 10X257_2:TCATACTCAGCACAGA               4065                 8.310415
# 10X257_2:TCCCATGTCGATTCCC               4657                 8.446341
# 10X257_4:ATTCCATCAGTGGTGA               3422                 8.138273
# 10X257_5:ATGCCTCAGGTCATTC               5606                 8.631771
# 10X257_6:GATCATGAGACCATGG               7034                 8.858653
#
#                            total_counts  log1p_total_counts  \
# AAACCCAAGAAGCGAA-1-NMR1          2298.0            7.740230
# AAACCCAAGGAGGCAG-1-NMR1          1777.0            7.483244
# AAACCCACAAATCAAG-1-NMR1           679.0            6.522093
# AAACCCACAGTCTACA-1-NMR1          3369.0            8.122668
# AAACCCAGTACGTAGG-1-NMR1           710.0            6.566672
# ...                                 ...                 ...
# 10X257_2:TCATACTCAGCACAGA       10290.0            9.239025
# 10X257_2:TCCCATGTCGATTCCC       14512.0            9.582800
# 10X257_4:ATTCCATCAGTGGTGA        7718.0            8.951440
# 10X257_5:ATGCCTCAGGTCATTC       20033.0            9.905186
# 10X257_6:GATCATGAGACCATGG       31324.0           10.352172
#
#                            pct_counts_in_top_50_genes  \
# AAACCCAAGAAGCGAA-1-NMR1                     14.882507
# AAACCCAAGGAGGCAG-1-NMR1                     14.350028
# AAACCCACAAATCAAG-1-NMR1                     29.602356
# AAACCCACAGTCTACA-1-NMR1                     19.709112
# AAACCCAGTACGTAGG-1-NMR1                     32.535211
# ...                                               ...
# 10X257_2:TCATACTCAGCACAGA                   15.617104
# 10X257_2:TCCCATGTCGATTCCC                   18.598401
# 10X257_4:ATTCCATCAGTGGTGA                   15.107541
# 10X257_5:ATGCCTCAGGTCATTC                   13.757300
# 10X257_6:GATCATGAGACCATGG                   13.762610
#
#                            pct_counts_in_top_100_genes  ...  Supercluster  \
# AAACCCAAGAAGCGAA-1-NMR1                      22.062663  ...           NaN
# AAACCCAAGGAGGCAG-1-NMR1                      21.890827  ...           NaN
# AAACCCACAAATCAAG-1-NMR1                      42.415317  ...           NaN
# AAACCCACAGTCTACA-1-NMR1                      27.634313  ...           NaN
# AAACCCAGTACGTAGG-1-NMR1                      46.760563  ...           NaN
# ...                                                ...  ...           ...
# 10X257_2:TCATACTCAGCACAGA                    21.632653  ...      Vascular
# 10X257_2:TCCCATGTCGATTCCC                    26.033627  ...      Vascular
# 10X257_4:ATTCCATCAGTGGTGA                    22.285566  ...      Vascular
# 10X257_5:ATGCCTCAGGTCATTC                    20.296511  ...      Vascular
# 10X257_6:GATCATGAGACCATGG                    20.188992  ...      Vascular
#
#                            Specific  \
# AAACCCAAGAAGCGAA-1-NMR1         NaN
# AAACCCAAGGAGGCAG-1-NMR1         NaN
# AAACCCACAAATCAAG-1-NMR1         NaN
# AAACCCACAGTCTACA-1-NMR1         NaN
# AAACCCAGTACGTAGG-1-NMR1         NaN
# ...                             ...
# 10X257_2:TCATACTCAGCACAGA     VendC
# 10X257_2:TCCCATGTCGATTCCC     VendC
# 10X257_4:ATTCCATCAGTGGTGA     VendC
# 10X257_5:ATGCCTCAGGTCATTC     VendC
# 10X257_6:GATCATGAGACCATGG     VendC
#
#                                                           Top Enriched Genes  \
# AAACCCAAGAAGCGAA-1-NMR1                                                  NaN
# AAACCCAAGGAGGCAG-1-NMR1                                                  NaN
# AAACCCACAAATCAAG-1-NMR1                                                  NaN
# AAACCCACAGTCTACA-1-NMR1                                                  NaN
# AAACCCAGTACGTAGG-1-NMR1                                                  NaN
# ...                                                                      ...
# 10X257_2:TCATACTCAGCACAGA  CLEC3B,FLT1,SOX18,CLDN5,ITM2A,SLC38A5,PECAM1,E...
# 10X257_2:TCCCATGTCGATTCCC  CLEC3B,FLT1,SOX18,CLDN5,ITM2A,SLC38A5,PECAM1,E...
# 10X257_4:ATTCCATCAGTGGTGA  CLEC3B,FLT1,SOX18,CLDN5,ITM2A,SLC38A5,PECAM1,E...
# 10X257_5:ATGCCTCAGGTCATTC  CLEC3B,FLT1,SOX18,CLDN5,ITM2A,SLC38A5,PECAM1,E...
# 10X257_6:GATCATGAGACCATGG  CLEC3B,FLT1,SOX18,CLDN5,ITM2A,SLC38A5,PECAM1,E...
#
#                             Age  CellClass         Region  Subregion  \
# AAACCCAAGAAGCGAA-1-NMR1     NaN        NaN            NaN        NaN
# AAACCCAAGGAGGCAG-1-NMR1     NaN        NaN            NaN        NaN
# AAACCCACAAATCAAG-1-NMR1     NaN        NaN            NaN        NaN
# AAACCCACAGTCTACA-1-NMR1     NaN        NaN            NaN        NaN
# AAACCCAGTACGTAGG-1-NMR1     NaN        NaN            NaN        NaN
# ...                         ...        ...            ...        ...
# 10X257_2:TCATACTCAGCACAGA  14.0   Vascular  Telencephalon     Cortex
# 10X257_2:TCCCATGTCGATTCCC  14.0   Vascular  Telencephalon     Cortex
# 10X257_4:ATTCCATCAGTGGTGA  14.0   Vascular  Telencephalon     Cortex
# 10X257_5:ATGCCTCAGGTCATTC  14.0   Vascular  Telencephalon     Cortex
# 10X257_6:GATCATGAGACCATGG  14.0   Vascular  Telencephalon     Cortex
#
#                            cell_cycle_score  total_genes    dataset
# AAACCCAAGAAGCGAA-1-NMR1                 NaN          NaN        nmr
# AAACCCAAGGAGGCAG-1-NMR1                 NaN          NaN        nmr
# AAACCCACAAATCAAG-1-NMR1                 NaN          NaN        nmr
# AAACCCACAGTCTACA-1-NMR1                 NaN          NaN        nmr
# AAACCCAGTACGTAGG-1-NMR1                 NaN          NaN        nmr
# ...                                     ...          ...        ...
# 10X257_2:TCATACTCAGCACAGA          0.000972         4065  human_dev
# 10X257_2:TCCCATGTCGATTCCC          0.001861         4657  human_dev
# 10X257_4:ATTCCATCAGTGGTGA          0.002591         3422  human_dev
# 10X257_5:ATGCCTCAGGTCATTC          0.001847         5606  human_dev
# 10X257_6:GATCATGAGACCATGG          0.001564         7034  human_dev
#
# [31043 rows x 45 columns]

# %% [markdown]
# ## Save Merged objects

# %%
for dataset in outer_datasets:
    dataset.var['mt-human_adult'].fillna(False, inplace=True)
    dataset.var['ribo-human_adult'].fillna(False, inplace=True)
    dataset.var['mt-human_dev'].fillna(False, inplace=True)
    dataset.var['ribo-human_dev'].fillna(False, inplace=True)
    dataset.var['mt-nmr'].fillna(False, inplace=True)
    dataset.var['ribo-nmr'].fillna(False, inplace=True)

# %%
filtered_adult_datasets[0].obs[['cluster_id', 'stage', 'species', 'region', 'Major Field', 'Supercluster',
       'Specific']]
# Out:
#                            cluster_id  stage species           region  \
# CellID
# 10X174_6:TCCGATCTCTTGGCTC           1  adult   human  cerebral cortex
# 10X221_7:GTGTTAGAGGCTGAAC           1  adult   human  cerebral cortex
# 10X269_8:GGGATGACAGTCGGTC           2  adult   human  cerebral cortex
# 10X382_1:CGGGTGTTCAATCTTC           6  adult   human  cerebral cortex
# 10X221_7:CGTAATGGTGTCATCA           6  adult   human  cerebral cortex
# ...                               ...    ...     ...              ...
# 10X159_3:CAGGGCTCACGCTGAC         460  adult   human  cerebral cortex
# 10X160_8:CATTGCCCATAGAATG         460  adult   human  cerebral cortex
# 10X159_1:AGTGCCGCAGGGAGAG         460  adult   human  cerebral cortex
# 10X160_7:CTTCTCTTCACCTGGG         460  adult   human  cerebral cortex
# 10X160_8:CCTAAGAGTCCGGTCA         460  adult   human  cerebral cortex
#
#                                  Major Field         Supercluster Specific
# CellID
# 10X174_6:TCCGATCTCTTGGCTC         Non-neuron        Miscellaneous    Tcell
# 10X221_7:GTGTTAGAGGCTGAAC         Non-neuron        Miscellaneous    Tcell
# 10X269_8:GGGATGACAGTCGGTC         Non-neuron        Miscellaneous   Nkcell
# 10X382_1:CGGGTGTTCAATCTTC         Non-neuron            Microglia      Mgl
# 10X221_7:CGTAATGGTGTCATCA         Non-neuron            Microglia      Mgl
# ...                                      ...                  ...      ...
# 10X159_3:CAGGGCTCACGCTGAC  Excitatory neuron  Thalamic excitatory     Thex
# 10X160_8:CATTGCCCATAGAATG  Excitatory neuron  Thalamic excitatory     Thex
# 10X159_1:AGTGCCGCAGGGAGAG  Excitatory neuron  Thalamic excitatory     Thex
# 10X160_7:CTTCTCTTCACCTGGG  Excitatory neuron  Thalamic excitatory     Thex
# 10X160_8:CCTAAGAGTCCGGTCA  Excitatory neuron  Thalamic excitatory     Thex
#
# [4665 rows x 7 columns]

# %%
outer_datasets[0].obs['cluster_id'].value_counts()
# Out:
# cluster_id
# 123.0    135
# 138.0    135
# 52.0     110
# 129.0     95
# 35.0      86
#         ...
# 97.0       1
# 578.0      1
# 246.0      1
# 60.0       1
# 65.0       1
# Name: count, Length: 324, dtype: int64

# %%
# Save objecs
for dataset in outer_datasets:
    region = dataset.obs['region'].iloc[0].replace(" ", "_")
    filename = f'/home/ratopin/big_data/combined/{region}_combined_outer_adata{rev_n}.h5ad'
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    dataset.write_h5ad(str(filename))
    print(f"Combined AnnData from {region} successfully saved to {filename}")
# Out:
# Combined AnnData from cerebral_cortex successfully saved to /home/ratopin/big_data/combined/cerebral_cortex_combined_outer_adata12.h5ad
# Combined AnnData from hippocampus successfully saved to /home/ratopin/big_data/combined/hippocampus_combined_outer_adata12.h5ad
# Combined AnnData from midbrain successfully saved to /home/ratopin/big_data/combined/midbrain_combined_outer_adata12.h5ad

# %%
filename
# Out:
# '/home/ratopin/big_data/combined/midbrain_combined_outer_adata12.h5ad'
